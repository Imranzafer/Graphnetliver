# %% [markdown]
# <a href="https://colab.research.google.com/github/Imranzafer/Graphnetliver/blob/main/Graphlivernet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("No GPU detected")
# Out:
# PyTorch: 2.11.0+cpu
# CUDA available: False
# No GPU detected

# %%
import torch
import subprocess

print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    subprocess.run(["nvidia-smi"])
else:
    print("No GPU detected")
# Out:
# PyTorch: 2.11.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-7ad8fc51-faed-4dda-8174-d15467ff9be2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ad8fc51-faed-4dda-8174-d15467ff9be2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
import zipfile

zip_path = "/content/GraphOmics_HCC_COMPLETE_RUNNABLE_WITH_RESULTS.zip"
extract_dir = "/content/GraphOmics_HCC"

with zipfile.ZipFile(zip_path, "r") as z:
    z.extractall(extract_dir)

print("Extracted to:", extract_dir)
print("\nTop-level files:")
print(os.listdir(extract_dir)[:20])
# Out:
# Extracted to: /content/GraphOmics_HCC
#
# Top-level files:
# ['GraphOmics_HCC_COMPLETE_RUNNABLE']

# %%
# !find /content/GraphOmics_HCC -maxdepth 2 -type f | head -50
# Out:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/SMOKE_TEST_RESULTS_SUMMARY.txt
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/00_CREATE_GPU_VM_IN_CLOUD_SHELL.sh
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/COMPLETE_CODE_REFERENCE.txt
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/WHAT_I_CAN_DO_FOR_YOU.txt
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/CODE_AUDIT_AND_CORRECTIONS.md
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/SMOKE_TEST_RESULT_SUMMARY.csv
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/SMOKE_TEST_RESULTS.md
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/COPY_PASTE_STEP_BY_STEP.md
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/README_GOOGLE_CLOUD.md
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/INPUT_DATA_MANIFEST.csv
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/RUN_SEQUENCE.txt

# %%
# !find /content/GraphOmics_HCC -maxdepth 2 -type f | head -50
# Out:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/SMOKE_TEST_RESULTS_SUMMARY.txt
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/00_CREATE_GPU_VM_IN_CLOUD_SHELL.sh
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/COMPLETE_CODE_REFERENCE.txt
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/WHAT_I_CAN_DO_FOR_YOU.txt
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/CODE_AUDIT_AND_CORRECTIONS.md
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/SMOKE_TEST_RESULT_SUMMARY.csv
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/SMOKE_TEST_RESULTS.md
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/COPY_PASTE_STEP_BY_STEP.md
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/README_GOOGLE_CLOUD.md
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/INPUT_DATA_MANIFEST.csv
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/RUN_SEQUENCE.txt

# %%
# %cd /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code
# Out:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code

# %%
# !pwd
# !ls -lah
# Out:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code
# total 96K
# drwxr-xr-x 11 root root 4.0K Sep 21 19:10 .
# drwxr-xr-x  6 root root 4.0K Sep 21 19:10 ..
# -rw-r--r--  1 root root 1.2K Sep 21 19:10 00_BOOTSTRAP_ENVIRONMENT.sh
# -rw-r--r--  1 root root  740 Sep 21 19:10 01_DOWNLOAD_PUBLIC_INPUTS.sh
# -rw-r--r--  1 root root 1.6K Sep 21 19:10 02_VERIFY_INPUTS.sh
# -rw-r--r--  1 root root 1.5K Sep 21 19:10 03_RUN_COMPLETE_REAL_ANALYSIS.sh
# -rw-r--r--  1 root root  739 Sep 21 19:10 04_COLLECT_RESULTS.sh
# -rw-r--r--  1 root root  655 Sep 21 19:10 check_inputs.sh
# drwxr-xr-x  2 root root 4.0K Sep 21 19:10 config
# drwxr-xr-x  5 root root 4.0K Sep 21 19:10 data
# -rw-r--r--  1 root root  518 Sep 21 19:10 download_real_inputs.sh
# drwxr-xr-x  2 root root 4.0K Sep 21 19:10 figures
# drwxr-xr-x  2 root root 4.0K Sep 21 19:10 figures_smoke
# drwxr-xr-x  3 root root 4.0K Sep 21 19:10 .pytest_cache
# -rw-r--r--  1 root root  291 Sep 21 19:10 requirements_cloud.txt
# ...

# %%
# !pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 102.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 97.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (pyproject.toml) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# ...

# %%
# !python --version
# Out:
# Python 3.13.15

# %%
# %cd /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code

# !python -m pip install -q --upgrade pip setuptools wheel

# !python -m pip install -q \
    "pandas>=2.2" \
    "scipy>=1.13" \
    "scikit-learn>=1.7" \
    "statsmodels>=0.14" \
    "networkx>=3.3" \
    "pyarrow>=16" \
    "pyyaml>=6.0" \
    "optuna>=4.0" \
    "xgboost>=2.0" \
    "shap>=0.45" \
    "lifelines>=0.30" \
    "scikit-survival==0.28.0" \
    "requests>=2.32" \
    "GEOparse==2.0.4" \
    "matplotlib>=3.9" \
    "seaborn>=0.13" \
    "pytest>=8.2"
# Out:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 32.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# torch 2.11.0+cu128 requires setuptools<82, but you have setuptools 84.0.0 which is incompatible.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import sys
import torch
import numpy
import pandas
import scipy
import sklearn
import statsmodels
import networkx
import pyarrow
import yaml
import optuna
import xgboost
import shap
import lifelines
import sksurv
import requests
import GEOparse
import matplotlib
import seaborn

print("Python:", sys.version.split()[0])
print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

print("NumPy:", numpy.__version__)
print("Pandas:", pandas.__version__)
print("SciPy:", scipy.__version__)
print("scikit-learn:", sklearn.__version__)
print("scikit-survival:", sksurv.__version__)
print("XGBoost:", xgboost.__version__)
print("SHAP:", shap.__version__)
print("lifelines:", lifelines.__version__)

print("\n✅ GraphOmics dependencies imported successfully.")
# Out:
# Python: 3.13.15
# PyTorch: 2.11.0+cu128
# CUDA available: True
# GPU: Tesla T4
# NumPy: 2.1.3
# Pandas: 2.2.3
# SciPy: 1.16.3
# scikit-learn: 1.9.1
# scikit-survival: 0.28.0
# XGBoost: 3.4.1
# SHAP: 0.52.0
# lifelines: 0.30.3
#
# ✅ GraphOmics dependencies imported successfully.

# %%
# %cd /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code

# !python -m pytest tests/ -q
# Out:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code
# ........................                                                 [100%]
# =============================== warnings summary ===============================
# tests/test_corrected_controls.py::test_gnnexplainer_masked_adjacency_is_differentiable
#   /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/05_explain.py:65: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:760.)
#     return torch.sparse_coo_tensor(torch.stack([src, dst]), vals,
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 24 passed, 1 warning in 8.82s

# %%
import torch

print("CUDA:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA: True
# GPU: Tesla T4

# %%
# %cd /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code

# !python -m pytest tests/ -q
# Out:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code
# ........................                                                 [100%]
# =============================== warnings summary ===============================
# tests/test_corrected_controls.py::test_gnnexplainer_masked_adjacency_is_differentiable
#   /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/05_explain.py:65: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:760.)
#     return torch.sparse_coo_tensor(torch.stack([src, dst]), vals,
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 24 passed, 1 warning in 8.88s

# %%
# !bash run_smoke_local.sh
# Out:
# ........................                                                 [100%]
# =============================== warnings summary ===============================
# tests/test_corrected_controls.py::test_gnnexplainer_masked_adjacency_is_differentiable
#   /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/05_explain.py:65: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:760.)
#     return torch.sparse_coo_tensor(torch.stack([src, dst]), vals,
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 24 passed, 1 warning in 7.31s
# synthetic dataset -> data/raw/synthetic
# ...

# %%
# !find results_smoke -maxdepth 1 -type f -printf "%f\n" | sort
# Out:
# cross_cohort_duplicates.csv
# explanation_stability.json
# gene_attributions_full.csv
# metrics_raw.json
# model_weights.pt
# pathway_activations.csv
# pathway_differential.csv
# predictions_graphomics.csv
# preprocessing_stats.json
# qc_exclusions.csv
# subnetwork_edges.graphml
# training_history.json

# %%
import json

with open("results_smoke/metrics_raw.json", "r") as f:
    metrics = json.load(f)

print(json.dumps(metrics, indent=2))
# Out:
# {
#   "config": {
#     "seed": 42,
#     "seeds": [
#       42,
#       43,
#       44,
#       45,
#       46
#     ],
#     "paths": {
#       "raw": "data/raw",
#       "processed": "data/processed_smoke",
#       "results": "results_smoke",
#       "figures": "figures_smoke",
#       "geo_label_maps": "config/geo_label_maps.yaml"
#     },
#     "cohorts": {
#       "development": "TCGA-LIHC",
#       "external": [
#         "COHORT-B",
#         "COHORT-C",
#         "COHORT-D"
#       ],
#       "geo": []
#     },
#     "geo_platforms": {
#       "GSE14520": "GPL3921"
#     },
#     "preprocess": {
#       "min_count": 10,
#       "min_frac": 0.2,
#       "min_cohort_coverage": 0.6,
#       "duplicate_threshold": 0.99,
#       "harmonisation": "rank"
#     },
#     "graph": {
#       "string_version": "12.0",
#       "string_cutoff": 700,
#       "msigdb_collection": "c2.cp.v2023.2.Hs.symbols.gmt",
#       "pathway_min_size": 10,
#       "pathway_max_size": 300,
# ...

# %%
# %cd /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code
# !pwd
# Out:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code

# %%
# !sed -n '1,220p' 01_DOWNLOAD_PUBLIC_INPUTS.sh
# Out:
# #!/usr/bin/env bash
# set -euo pipefail
# cd "$(dirname "$0")"
# source .venv/bin/activate
# mkdir -p data/raw/{tcga,geo,string,msigdb} data/processed results figures
# LOG="results/download_public_inputs.log"
# exec > >(tee -a "$LOG") 2>&1
#
# echo "=== Downloading public GraphOmics-HCC inputs ==="
# date
# python src/01_download_data.py --config config/config.yaml --only tcga
# python src/01_download_data.py --config config/config.yaml --only geo
# python src/01_download_data.py --config config/config.yaml --only string
# python src/validate_geo_labels.py
#
# echo
# echo "Public inputs downloaded."
# echo "MSigDB is NOT downloaded automatically because its distribution requires registered access."
# echo "Place c2.cp.v2023.2.Hs.symbols.gmt in data/raw/msigdb/."

# %%
# %cd /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code

# !mkdir -p data/raw/tcga
# !mkdir -p data/raw/geo
# !mkdir -p data/raw/string
# !mkdir -p data/raw/msigdb
# !mkdir -p data/processed
# !mkdir -p results
# !mkdir -p figures

print("Folders ready.")
# Out:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code
# Folders ready.

# %%
# !python src/01_download_data.py \
    --config config/config.yaml \
    --only tcga
# Out:
# TCGA-LIHC
#   querying GDC file manifest ...
#   421 files (371 tumour, 50 normal)
#   downloading expression files (this takes a while) ...
#   fetching clinical / survival fields ...
#
# provenance written to results/provenance.json

# %%
# !find data/raw/tcga -type f | head -30
# Out:
# data/raw/tcga/tcga_lihc_star.tar.gz
# data/raw/tcga/tcga_lihc_counts.parquet
# data/raw/tcga/tcga_lihc_clinical.csv
# data/raw/tcga/tcga_lihc_labels.csv
# data/raw/tcga/tcga_lihc_manifest.csv

# %%
# !du -sh data/raw/tcga
# Out:
# 409M	data/raw/tcga

# %%
import os

root = "data/raw/tcga"

for path, dirs, files in os.walk(root):
    if files:
        print("\nFolder:", path)
        print("Files:", len(files))
        for f in files[:10]:
            print("  ", f)
# Out:
# Folder: data/raw/tcga
# Files: 5
#    tcga_lihc_star.tar.gz
#    tcga_lihc_counts.parquet
#    tcga_lihc_clinical.csv
#    tcga_lihc_labels.csv
#    tcga_lihc_manifest.csv

# %%
# !python src/01_download_data.py \
    --config config/config.yaml \
    --only geo
# Out:
# GEO series
#   GSE14520 ...
#     using platform GPL3921: 445 samples
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/01_download_data.py:242: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   is_t_raw = blob.str.contains(tumour_pat.lower(), regex=True, na=False)
#   GSE25097 ...
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/01_download_data.py:242: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   is_t_raw = blob.str.contains(tumour_pat.lower(), regex=True, na=False)
#     46 unmatched/extra-class samples — excluded, logged
#   GSE36376 ...
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/01_download_data.py:242: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
# ...

# %%
# !du -sh data/raw/geo/*
# Out:
# 29M	data/raw/geo/GSE14520_expr.parquet
# 64M	data/raw/geo/GSE14520_family.soft.gz
# 25M	data/raw/geo/GSE14520_GPL3921_platform.csv
# 68K	data/raw/geo/GSE14520_metadata.csv
# 193M	data/raw/geo/GSE25097_expr.parquet
# 169M	data/raw/geo/GSE25097_family.soft.gz
# 2.3M	data/raw/geo/GSE25097_GPL10687_platform.csv
# 40K	data/raw/geo/GSE25097_metadata.csv
# 194M	data/raw/geo/GSE36376_expr.parquet
# 247M	data/raw/geo/GSE36376_family.soft.gz
# 69M	data/raw/geo/GSE36376_GPL10558_platform.csv
# 48K	data/raw/geo/GSE36376_metadata.csv
# 39M	data/raw/geo/GSE64041_expr.parquet
# 45M	data/raw/geo/GSE64041_family.soft.gz
# 95M	data/raw/geo/GSE64041_GPL6244_platform.csv
# 20K	data/raw/geo/GSE64041_metadata.csv
# 31M	data/raw/geo/GSE76427_expr.parquet
# 67M	data/raw/geo/GSE76427_family.soft.gz
# 69M	data/raw/geo/GSE76427_GPL10558_platform.csv
# 52K	data/raw/geo/GSE76427_metadata.csv

# %%
# !python src/validate_geo_labels.py
# Out:
# GEO label audit
# ...
# GSE14520: tumour=225 (expected 225), non-tumour=220 (expected 220), unmatched=0 -> OK
# GSE25097: tumour=511 (expected 268), non-tumour=0 (expected 243), unmatched=46 -> CHECK
#   unmatched/extra-class examples:
#    sample              title    source         characteristics platform_id
# GSM616704   healthy sample 1   healthy   tissue: healthy liver    GPL10687
# GSM616705   healthy sample 2   healthy   tissue: healthy liver    GPL10687
# GSM616706   healthy sample 3   healthy   tissue: healthy liver    GPL10687
# GSM616707   healthy sample 4   healthy   tissue: healthy liver    GPL10687
# GSM616708   healthy sample 5   healthy   tissue: healthy liver    GPL10687
# GSM616709   healthy sample 6   healthy   tissue: healthy liver    GPL10687
# GSM616710 cirrhotic sample 1 cirrhotic tissue: cirrhotic liver    GPL10687
# GSM616711 cirrhotic sample 2 cirrhotic tissue: cirrhotic liver    GPL10687
# ...

# %%
# !python src/01_download_data.py \
    --config config/config.yaml \
    --only string
# Out:
# STRING
#   STRING links ...
#   STRING info ...
#
# provenance written to results/provenance.json

# %%
# !find data/raw/string -type f -maxdepth 2 -printf "%f\n"
# Out:
# find: warning: you have specified the global option -maxdepth after the argument -type, but global options are not positional, i.e., -maxdepth affects tests specified before it as well as those specified after it.  Please specify global options before other arguments.
# 9606.protein.links.v12.0.txt.gz
# 9606.protein.info.v12.0.txt.gz

# %%
import pandas as pd

path = "data/raw/geo/GSE25097_metadata.csv"
df = pd.read_csv(path)

pd.set_option("display.max_colwidth", 250)
pd.set_option("display.max_rows", 100)

print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

print("\nFIRST 20 ROWS")
print(
    df[["sample", "title", "source", "characteristics", "tumour"]]
    .head(20)
    .to_string(index=False)
)

print("\nROWS 40-70")
print(
    df[["sample", "title", "source", "characteristics", "tumour"]]
    .iloc[40:70]
    .to_string(index=False)
)

print("\nROWS 300-330")
print(
    df[["sample", "title", "source", "characteristics", "tumour"]]
    .iloc[300:330]
    .to_string(index=False)
)
# Out:
# Shape: (557, 6)
#
# Columns:
# ['sample', 'title', 'source', 'characteristics', 'platform_id', 'tumour']
#
# FIRST 20 ROWS
#    sample               title    source         characteristics  tumour
# GSM616704    healthy sample 1   healthy   tissue: healthy liver     NaN
# GSM616705    healthy sample 2   healthy   tissue: healthy liver     NaN
# GSM616706    healthy sample 3   healthy   tissue: healthy liver     NaN
# GSM616707    healthy sample 4   healthy   tissue: healthy liver     NaN
# GSM616708    healthy sample 5   healthy   tissue: healthy liver     NaN
# GSM616709    healthy sample 6   healthy   tissue: healthy liver     NaN
# GSM616710  cirrhotic sample 1 cirrhotic tissue: cirrhotic liver     NaN
# GSM616711  cirrhotic sample 2 cirrhotic tissue: cirrhotic liver     NaN
# GSM616712  cirrhotic sample 3 cirrhotic tissue: cirrhotic liver     NaN
# GSM616713  cirrhotic sample 4 cirrhotic tissue: cirrhotic liver     NaN
# ...

# %%
for col in ["title", "source", "characteristics"]:
    print("\n" + "="*80)
    print(col.upper())

    s = df[col].fillna("").astype(str).str.lower()

    patterns = [
        "tumor",
        "tumour",
        "hcc",
        "adjacent",
        "non-tumor",
        "nontumor",
        "non tumor",
        "normal",
        "healthy",
        "cirrho",
        "paired",
        "liver",
        "noncancer",
        "non-cancer"
    ]

    for p in patterns:
        print(f"{p:15s}: {s.str.contains(p, regex=False).sum()}")
# Out:
# ...
# TITLE
# tumor          : 511
# tumour         : 0
# hcc            : 0
# adjacent       : 0
# non-tumor      : 0
# nontumor       : 0
# non tumor      : 0
# normal         : 0
# healthy        : 6
# cirrho         : 40
# paired         : 0
# liver          : 0
# noncancer      : 0
# non-cancer     : 0
#
# ...
# SOURCE
# tumor          : 511
# tumour         : 0
# hcc            : 0
# adjacent       : 0
# non-tumor      : 0
# nontumor       : 0
# non tumor      : 0
# normal         : 0
# healthy        : 6
# cirrho         : 40
# paired         : 0
# liver          : 0
# noncancer      : 0
# non-cancer     : 0
#
# ...
# CHARACTERISTICS
# tumor          : 511
# tumour         : 0
# hcc            : 0
# adjacent       : 0
# non-tumor      : 0
# nontumor       : 0
# non tumor      : 0
# normal         : 0
# healthy        : 6
# cirrho         : 40
# paired         : 0
# liver          : 557
# noncancer      : 0
# non-cancer     : 0

# %%
print("\nMost common SOURCE values:")
print(df["source"].value_counts().head(30))

print("\nMost common TITLE prefixes:")
print(
    df["title"]
      .astype(str)
      .str.replace(r"\d+$", "", regex=True)
      .value_counts()
      .head(30)
)
# Out:
# Most common SOURCE values:
# source
# tumor        268
# non_tumor    243
# cirrhotic     40
# healthy        6
# Name: count, dtype: int64
#
# Most common TITLE prefixes:
# title
# tumor sample         268
# non_tumor sample     243
# cirrhotic sample      40
# healthy sample         6
# Name: count, dtype: int64

# %%
import pandas as pd
from pathlib import Path

path = Path("data/raw/geo/GSE25097_metadata.csv")

df = pd.read_csv(path)

# Keep original as backup
backup = path.with_name("GSE25097_metadata_ORIGINAL.csv")
df.to_csv(backup, index=False)

# Robust source-based labels
source = df["source"].astype(str).str.strip().str.lower()

df["tumour"] = pd.NA

df.loc[source.eq("tumor"), "tumour"] = 1
df.loc[source.eq("non_tumor"), "tumour"] = 0

# cirrhotic + healthy remain NA and are excluded
df.to_csv(path, index=False)

print("Updated:", path)
print("Backup :", backup)

print("\nSource counts:")
print(source.value_counts())

print("\nTumour label counts:")
print(df["tumour"].value_counts(dropna=False))
# Out:
# Updated: data/raw/geo/GSE25097_metadata.csv
# Backup : data/raw/geo/GSE25097_metadata_ORIGINAL.csv
#
# Source counts:
# source
# tumor        268
# non_tumor    243
# cirrhotic     40
# healthy        6
# Name: count, dtype: int64
#
# Tumour label counts:
# tumour
# 1       268
# 0       243
# <NA>     46
# Name: count, dtype: int64

# %%
# !python src/validate_geo_labels.py
# Out:
# GEO label audit
# ...
# GSE14520: tumour=225 (expected 225), non-tumour=220 (expected 220), unmatched=0 -> OK
# GSE25097: tumour=268 (expected 268), non-tumour=243 (expected 243), unmatched=46 -> OK
#   unmatched/extra-class examples:
#    sample              title    source         characteristics platform_id
# GSM616704   healthy sample 1   healthy   tissue: healthy liver    GPL10687
# GSM616705   healthy sample 2   healthy   tissue: healthy liver    GPL10687
# GSM616706   healthy sample 3   healthy   tissue: healthy liver    GPL10687
# GSM616707   healthy sample 4   healthy   tissue: healthy liver    GPL10687
# GSM616708   healthy sample 5   healthy   tissue: healthy liver    GPL10687
# GSM616709   healthy sample 6   healthy   tissue: healthy liver    GPL10687
# GSM616710 cirrhotic sample 1 cirrhotic tissue: cirrhotic liver    GPL10687
# GSM616711 cirrhotic sample 2 cirrhotic tissue: cirrhotic liver    GPL10687
# ...

# %%
from pathlib import Path

yaml_path = Path("config/geo_label_maps.yaml")
text = yaml_path.read_text()

old = """GSE25097:
  tumour: '(^|[^a-z])tumou?r([^a-z]|$)|(^|[^a-z])hcc([^a-z]|$)'
  non_tumour: 'adjacent|non[- ]?tumou?r'
  extra_classes:
    cirrhotic: 'cirrho'
    healthy: 'healthy|normal'
"""

new = """GSE25097:
  label_field: source
  tumour: '^tumor$'
  non_tumour: '^non_tumor$'
  extra_classes:
    cirrhotic: '^cirrhotic$'
    healthy: '^healthy$'
"""

if old in text:
    text = text.replace(old, new)
    yaml_path.write_text(text)
    print("✅ GSE25097 YAML rule updated.")
elif "label_field: source" in text:
    print("✅ GSE25097 YAML already updated.")
else:
    print("Please inspect YAML manually — expected block not found.")
# Out:
# ✅ GSE25097 YAML rule updated.

# %%
from pathlib import Path

p = Path("src/01_download_data.py")
text = p.read_text()

old = '''            blob = (meta["title"] + " || " + meta["source"] + " || " +
                    meta["characteristics"]).str.lower()
'''

new = '''            # A cohort may specify a particular metadata field for labeling.
            # This avoids disease-diagnosis text contaminating tissue labels.
            label_field = rules.get("label_field")
            if label_field and label_field in meta.columns:
                blob = meta[label_field].fillna("").astype(str).str.strip().str.lower()
            else:
                blob = (
                    meta["title"].fillna("").astype(str)
                    + " || "
                    + meta["source"].fillna("").astype(str)
                    + " || "
                    + meta["characteristics"].fillna("").astype(str)
                ).str.lower()
'''

if old in text:
    p.write_text(text.replace(old, new))
    print("✅ Downloader permanently patched.")
elif 'label_field = rules.get("label_field")' in text:
    print("✅ Downloader already patched.")
else:
    print("Expected code block not found — do not overwrite manually.")
# Out:
# ✅ Downloader permanently patched.

# %%
# !grep -A7 "GSE25097:" config/geo_label_maps.yaml
# Out:
# GSE25097:
#   label_field: source
#   tumour: '^tumor$'
#   non_tumour: '^non_tumor$'
#   extra_classes:
#     cirrhotic: '^cirrhotic$'
#     healthy: '^healthy$'

# %%
from pathlib import Path

p = Path("src/02_preprocess.py")
text = p.read_text()

old = '''    if symbol_col is None:
        raise ValueError(f"no gene-symbol column found in platform table; columns: "
                         f"{list(platform.columns)[:15]}")

    mapping = {}
    for pid, sym in zip(platform[id_col], platform[symbol_col]):
        if pd.isna(sym):
            continue
        # multi-mapping probes are dropped rather than assigned arbitrarily:
        # a probe matching several genes cannot attribute signal to one of them
        s = str(sym).split("///")[0].split("//")[0].strip()
        if s and s not in {"---", "NA", "nan"} and "///" not in str(sym):
            mapping[str(pid)] = s
'''

new = '''    assignment_col = None
    if symbol_col is None:
        # GPL6244 (Affymetrix Human Gene 1.0 ST), used by GSE64041,
        # stores annotation in gene_assignment rather than a dedicated
        # gene-symbol column.
        assignment_col = next(
            (c for c in platform.columns if _norm_col(c) == "geneassignment"),
            None,
        )
        if assignment_col is None:
            raise ValueError(
                f"no gene-symbol or gene_assignment column found in platform table; "
                f"columns: {list(platform.columns)[:15]}"
            )

    def _clean_symbol(value):
        if pd.isna(value):
            return None
        s = str(value).strip()
        if not s or s.lower() in {"---", "na", "nan", "null", "none"}:
            return None
        return s

    def _symbol_from_gene_assignment(value):
        if pd.isna(value):
            return None

        symbols = []

        # Affymetrix assignments can contain multiple entries separated by ///
        # and individual fields separated by //.
        for assignment in str(value).split("///"):
            parts = [x.strip() for x in assignment.split("//")]

            if len(parts) < 2:
                continue

            sym = _clean_symbol(parts[1])

            if sym is not None:
                symbols.append(sym)

        unique = list(dict.fromkeys(symbols))

        # Retain only unambiguous mappings.
        return unique[0] if len(unique) == 1 else None

    mapping = {}

    if symbol_col is not None:
        for pid, sym in zip(platform[id_col], platform[symbol_col]):

            if pd.isna(sym):
                continue

            raw = str(sym)

            pieces = [
                x.strip()
                for x in raw.split("///")
                if x.strip()
            ]

            cleaned = [
                _clean_symbol(
                    x.split("//")[0].strip()
                )
                for x in pieces
            ]

            cleaned = [
                x for x in cleaned
                if x is not None
            ]

            unique = list(dict.fromkeys(cleaned))

            if len(unique) == 1:
                mapping[str(pid)] = unique[0]

    else:
        for pid, assignment in zip(
            platform[id_col],
            platform[assignment_col]
        ):

            sym = _symbol_from_gene_assignment(
                assignment
            )

            if sym is not None:
                mapping[str(pid)] = sym

    if not mapping:
        raise ValueError(
            f"platform annotation produced zero unambiguous "
            f"probe-to-gene mappings "
            f"(symbol_col={symbol_col!r}, "
            f"assignment_col={assignment_col!r})"
        )
'''

if old in text:
    p.write_text(text.replace(old, new))
    print("✅ GSE64041 / GPL6244 parser patched successfully.")
elif "assignment_col = None" in text and "_symbol_from_gene_assignment" in text:
    print("✅ Parser already patched.")
else:
    print("⚠️ Expected source block not found. Do not continue yet.")
# Out:
# ✅ GSE64041 / GPL6244 parser patched successfully.

# %%
# !grep -n -A45 "assignment_col = None" src/02_preprocess.py
# Out:
# 101:    assignment_col = None
# 102-    if symbol_col is None:
# 103-        # GPL6244 (Affymetrix Human Gene 1.0 ST), used by GSE64041,
# 104-        # stores annotation in gene_assignment rather than a dedicated
# 105-        # gene-symbol column.
# 106-        assignment_col = next(
# 107-            (c for c in platform.columns if _norm_col(c) == "geneassignment"),
# 108-            None,
# 109-        )
# 110-        if assignment_col is None:
# 111-            raise ValueError(
# 112-                f"no gene-symbol or gene_assignment column found in platform table; "
# 113-                f"columns: {list(platform.columns)[:15]}"
# 114-            )
# 115-
# 116-    def _clean_symbol(value):
# 117-        if pd.isna(value):
# 118-            return None
# 119-        s = str(value).strip()
# 120-        if not s or s.lower() in {"---", "na", "nan", "null", "none"}:
# 121-            return None
# 122-        return s
# 123-
# 124-    def _symbol_from_gene_assignment(value):
# ...

# %%
import pandas as pd

platform = pd.read_csv(
    "data/raw/geo/GSE64041_GPL6244_platform.csv"
)

print("Columns:")
print(platform.columns.tolist())

print("\nExample GPL6244 annotations:")
print(
    platform[["ID", "gene_assignment"]]
    .dropna()
    .head(20)
    .to_string(index=False)
)
# Out:
# Columns:
# ['ID', 'GB_LIST', 'SPOT_ID', 'seqname', 'RANGE_GB', 'RANGE_STRAND', 'RANGE_START', 'RANGE_STOP', 'total_probes', 'gene_assignment', 'mrna_assignment', 'category']
#
# Example GPL6244 annotations:
# ...

# %%
import pandas as pd

platform = pd.read_csv(
    "data/raw/geo/GSE64041_GPL6244_platform.csv"
)

def clean_symbol(value):
    if pd.isna(value):
        return None

    s = str(value).strip()

    if not s or s.lower() in {
        "---",
        "na",
        "nan",
        "null",
        "none"
    }:
        return None

    return s


def symbol_from_gene_assignment(value):

    if pd.isna(value):
        return None

    symbols = []

    for assignment in str(value).split("///"):

        parts = [
            x.strip()
            for x in assignment.split("//")
        ]

        if len(parts) < 2:
            continue

        sym = clean_symbol(parts[1])

        if sym is not None:
            symbols.append(sym)

    unique = list(
        dict.fromkeys(symbols)
    )

    return (
        unique[0]
        if len(unique) == 1
        else None
    )


platform["parsed_symbol"] = (
    platform["gene_assignment"]
    .apply(symbol_from_gene_assignment)
)

print("Total platform rows:",
      len(platform))

print(
    "Rows with usable gene symbol:",
    platform["parsed_symbol"].notna().sum()
)

print(
    "Mapping percentage:",
    round(
        platform["parsed_symbol"]
        .notna()
        .mean() * 100,
        2
    ),
    "%"
)

print("\nExample mappings:")

print(
    platform[
        ["ID",
         "gene_assignment",
         "parsed_symbol"]
    ]
    .dropna(subset=["parsed_symbol"])
    .head(20)
    .to_string(index=False)
)
# Out:
# Total platform rows: 33297
# Rows with usable gene symbol: 22153
# Mapping percentage: 66.53 %
#
# Example mappings:
# ...

# %%
# %cd /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code

# !python -m pytest tests/ -q
# Out:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code
# ........................                                                 [100%]
# =============================== warnings summary ===============================
# tests/test_corrected_controls.py::test_gnnexplainer_masked_adjacency_is_differentiable
#   /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/05_explain.py:65: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:760.)
#     return torch.sparse_coo_tensor(torch.stack([src, dst]), vals,
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 24 passed, 1 warning in 6.67s

# %%
# !python src/02_preprocess.py \
    --config config/config.yaml
# Out:
# TCGA-LIHC
#     15412/19938 genes pass expression filter
# GSE14520
# GSE25097
# GSE36376
# GSE76427
#     linear scale detected -> log2(x+1)
# GSE64041
#
#   96 samples flagged as outliers and excluded
#   vocabulary: 13084 genes present in >= 4/6 cohorts
#   harmonising (within-sample rank normalisation) ...
#   checking for cross-cohort duplicate samples ...
#     none found
#
#   2052 samples x 13084 genes -> data/processed/expression.parquet

# %%
import pandas as pd
import json

X = pd.read_parquet("data/processed/expression.parquet")
C = pd.read_parquet("data/processed/coverage.parquet")
S = pd.read_csv("data/processed/sample_table.csv")

print("=" * 75)
print("FINAL REAL GRAPHOMICS-HCC PREPROCESSED DATA")
print("=" * 75)

print("\nExpression matrix:", X.shape)
print("Coverage matrix:", C.shape)
print("Sample table:", S.shape)

print("\nCOHORT × CLASS")
print(
    pd.crosstab(
        S["cohort"],
        S["tumour"],
        margins=True
    )
)

print("\nExpression range")
print("Minimum:", float(X.min().min()))
print("Maximum:", float(X.max().max()))
print("Missing values:", int(X.isna().sum().sum()))

print("\nCoverage values")
print(sorted(pd.unique(C.values.ravel())))
# Out:
# ...
# FINAL REAL GRAPHOMICS-HCC PREPROCESSED DATA
# ...
#
# Expression matrix: (2052, 13084)
# Coverage matrix: (6, 13084)
# Sample table: (2001, 3)
#
# COHORT × CLASS
# tumour       0     1   All
# cohort
# GSE14520   210   208   418
# GSE25097   241   251   492
# GSE36376   188   230   418
# GSE64041    57    54   111
# GSE76427    48   113   161
# TCGA-LIHC   50   351   401
# All        794  1207  2001
#
# Expression range
# Minimum: 0.0
# Maximum: 1.0
# Missing values: 0
#
# Coverage values
# [np.False_, np.True_]

# %%
qc = pd.read_csv("results/qc_exclusions.csv")

print("QC file rows:", len(qc))
print("Columns:", qc.columns.tolist())

print("\nFirst rows:")
display(qc.head(20))
# Out:
# QC file rows: 2148
# Columns: ['sample', 'cohort', 'mean_correlation', 'excluded', 'reason']
#
# First rows:
#               sample     cohort  mean_correlation  excluded reason
# 0   TCGA-DD-AAE6-01A  TCGA-LIHC          0.837599     False    NaN
# 1   TCGA-BW-A5NO-01A  TCGA-LIHC          0.872948     False    NaN
# 2   TCGA-DD-AAD0-01A  TCGA-LIHC          0.846681     False    NaN
# 3   TCGA-DD-A1EL-11A  TCGA-LIHC          0.878905     False    NaN
# 4   TCGA-CC-A123-01A  TCGA-LIHC          0.835734     False    NaN
# 5   TCGA-2Y-A9GT-01A  TCGA-LIHC          0.873095     False    NaN
# 6   TCGA-DD-A119-11A  TCGA-LIHC          0.867225     False    NaN
# 7   TCGA-5C-A9VH-01A  TCGA-LIHC          0.876338     False    NaN
# 8   TCGA-DD-AAW1-01A  TCGA-LIHC          0.861568     False    NaN
# 9   TCGA-CC-A9FU-01A  TCGA-LIHC          0.829310     False    NaN
# 10  TCGA-DD-A1EB-11A  TCGA-LIHC          0.870204     False    NaN
# ...

# %%
# Find the sample identifier automatically
possible_ids = [
    "sample",
    "sample_id",
    "sample_name",
    "id"
]

sample_col = next(
    (c for c in possible_ids if c in qc.columns),
    None
)

print("Sample identifier column:", sample_col)

if "excluded" in qc.columns:
    flagged = qc[qc["excluded"] == True].copy()

    print("\nFlag rows:", len(flagged))

    if sample_col:
        print(
            "Unique excluded samples:",
            flagged[sample_col].nunique()
        )

        print("\nUnique excluded samples by cohort:")
        print(
            flagged.drop_duplicates(sample_col)
            .groupby("cohort")
            .size()
        )
# Out:
# Sample identifier column: sample
#
# Flag rows: 96
# Unique excluded samples: 96
#
# Unique excluded samples by cohort:
# cohort
# GSE14520     27
# GSE25097     19
# GSE36376     15
# GSE64041      9
# GSE76427      6
# TCGA-LIHC    20
# dtype: int64

# %%
cohort_counts = (
    S.groupby(["cohort", "tumour"])
     .size()
     .unstack(fill_value=0)
)

cohort_counts.columns = [
    "non_tumour" if c == 0 else "tumour"
    for c in cohort_counts.columns
]

cohort_counts["total"] = cohort_counts.sum(axis=1)

display(cohort_counts)
# Out:
#            non_tumour  tumour  total
# cohort
# GSE14520          210     208    418
# GSE25097          241     251    492
# GSE36376          188     230    418
# GSE64041           57      54    111
# GSE76427           48     113    161
# TCGA-LIHC          50     351    401

# %%
print(
    "Duplicated expression sample IDs:",
    X.index.duplicated().sum()
)

print(
    "Duplicated sample-table IDs:",
    S["sample"].duplicated().sum()
    if "sample" in S.columns
    else "sample column not found"
)
# Out:
# Duplicated expression sample IDs: 0
# Duplicated sample-table IDs: 0

# %%
from pathlib import Path

p = Path("src/02_preprocess.py")
text = p.read_text()

old = '''            cohort_frames[gse] = prepare_microarray(e, p)
            m = m.dropna(subset=["tumour"])
            m["cohort"] = gse
            meta_frames.append(m[["sample", "cohort", "tumour"]])
'''

new = '''            cohort_frames[gse] = prepare_microarray(e, p)

            # Primary analysis includes only samples with an explicit
            # tumour/non-tumour label. Extra biological classes such as
            # healthy liver and cirrhotic liver are excluded BEFORE QC,
            # harmonisation, duplicate detection and model-input creation.
            m = m.dropna(subset=["tumour"]).copy()

            valid_samples = set(
                m["sample"].astype(str)
            )

            cohort_frames[gse] = cohort_frames[gse].loc[
                :,
                [
                    s for s in cohort_frames[gse].columns
                    if str(s) in valid_samples
                ]
            ]

            m["cohort"] = gse
            meta_frames.append(
                m[["sample", "cohort", "tumour"]]
            )
'''

if old in text:
    p.write_text(text.replace(old, new))
    print("✅ Extra-class filtering patch applied.")
elif "Extra biological classes such as" in text:
    print("✅ Patch already present.")
else:
    print("⚠️ Expected block not found. Do not overwrite manually.")
# Out:
# ✅ Extra-class filtering patch applied.

# %%
# !grep -n -A30 "Primary analysis includes only" src/02_preprocess.py
# Out:
# 295:            # Primary analysis includes only samples with an explicit
# 296-            # tumour/non-tumour label. Extra biological classes such as
# 297-            # healthy liver and cirrhotic liver are excluded BEFORE QC,
# 298-            # harmonisation, duplicate detection and model-input creation.
# 299-            m = m.dropna(subset=["tumour"]).copy()
# 300-
# 301-            valid_samples = set(
# 302-                m["sample"].astype(str)
# 303-            )
# 304-
# 305-            cohort_frames[gse] = cohort_frames[gse].loc[
# 306-                :,
# 307-                [
# 308-                    s for s in cohort_frames[gse].columns
# 309-                    if str(s) in valid_samples
# 310-                ]
# 311-            ]
# 312-
# 313-            m["cohort"] = gse
# 314-            meta_frames.append(
# 315-                m[["sample", "cohort", "tumour"]]
# 316-            )
# 317-
# 318-        samples = pd.concat(meta_frames, ignore_index=True)
# 319-
# ...

# %%
from pathlib import Path

p = Path("src/02_preprocess.py")
text = p.read_text()

old = '''    sample_table = samples[samples["sample"].isin(harmonised.index)].copy()
    sample_table["tumour"] = sample_table["tumour"].astype(int)
    sample_table.to_csv(os.path.join(proc, "sample_table.csv"), index=False)

    stats = {
'''

new = '''    sample_table = samples[samples["sample"].isin(harmonised.index)].copy()
    sample_table["tumour"] = sample_table["tumour"].astype(int)

    # Strict alignment check: every expression row must have one label,
    # and every labelled sample must be present in the expression matrix.
    labelled_samples = set(sample_table["sample"].astype(str))
    expression_samples = set(harmonised.index.astype(str))

    if labelled_samples != expression_samples:
        extra_expr = sorted(expression_samples - labelled_samples)
        missing_expr = sorted(labelled_samples - expression_samples)

        raise RuntimeError(
            "Expression/sample-table mismatch after preprocessing. "
            f"Expression-only samples={len(extra_expr)}, "
            f"label-only samples={len(missing_expr)}. "
            f"Examples expression-only={extra_expr[:10]}, "
            f"label-only={missing_expr[:10]}"
        )

    # Keep exactly the same sample order in both outputs.
    sample_table = (
        sample_table
        .set_index("sample")
        .loc[harmonised.index]
        .reset_index()
    )

    sample_table.to_csv(
        os.path.join(proc, "sample_table.csv"),
        index=False
    )

    stats = {
'''

if old in text:
    p.write_text(text.replace(old, new))
    print("✅ Strict expression/label alignment check added.")
elif "Expression/sample-table mismatch after preprocessing" in text:
    print("✅ Alignment check already present.")
else:
    print("⚠️ Expected block not found.")
# Out:
# ✅ Strict expression/label alignment check added.

# %%
from pathlib import Path

p = Path("src/02_preprocess.py")

text = p.read_text()

old = '"n_samples": int(len(harmonised)),'
new = '"n_samples": int(len(sample_table)),'

if old in text:
    text = text.replace(old, new)
    p.write_text(text)
    print("✅ n_samples changed to labeled analytic sample count.")
elif new in text:
    print("✅ n_samples is already corrected.")
else:
    print("⚠️ Could not find the expected n_samples line.")
# Out:
# ✅ n_samples changed to labeled analytic sample count.

# %%
# !grep -n '"n_samples"' src/02_preprocess.py
# Out:
# 407:        "n_samples": int(len(sample_table)),

# %%
# !python -m pytest tests/ -q
# Out:
# ........................                                                 [100%]
# =============================== warnings summary ===============================
# tests/test_corrected_controls.py::test_gnnexplainer_masked_adjacency_is_differentiable
#   /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/05_explain.py:65: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:760.)
#     return torch.sparse_coo_tensor(torch.stack([src, dst]), vals,
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 24 passed, 1 warning in 6.48s

# %%
# !rm -rf data/processed/*
# !rm -f results/preprocessing_stats.json
# !rm -f results/qc_exclusions.csv
# !rm -f results/cross_cohort_duplicates.csv

# %%
# !python src/02_preprocess.py \
    --config config/config.yaml
# Out:
# TCGA-LIHC
#     15412/19938 genes pass expression filter
# GSE14520
# GSE25097
# GSE36376
# GSE76427
#     linear scale detected -> log2(x+1)
# GSE64041
#
#   95 samples flagged as outliers and excluded
#   vocabulary: 13084 genes present in >= 4/6 cohorts
#   harmonising (within-sample rank normalisation) ...
#   checking for cross-cohort duplicate samples ...
#     none found
#
#   2002 samples x 13084 genes -> data/processed/expression.parquet

# %%
import pandas as pd

S = pd.read_csv("data/processed/sample_table.csv")

print("Columns:", S.columns.tolist())
print()
print(S.head())
# Out:
# Columns: ['index', 'tumour', 'cohort']
#
#               index  tumour     cohort
# 0  TCGA-DD-AAE6-01A       1  TCGA-LIHC
# 1  TCGA-BW-A5NO-01A       1  TCGA-LIHC
# 2  TCGA-DD-AAD0-01A       1  TCGA-LIHC
# 3  TCGA-DD-A1EL-11A       0  TCGA-LIHC
# 4  TCGA-CC-A123-01A       1  TCGA-LIHC

# %%
import pandas as pd

S = pd.read_csv("data/processed/sample_table.csv")

# Identify the one column that is not cohort or tumour
id_candidates = [
    c for c in S.columns
    if c not in {"cohort", "tumour"}
]

print("Possible sample-ID columns:", id_candidates)

if len(id_candidates) != 1:
    raise RuntimeError(
        f"Could not uniquely identify sample ID column: {S.columns.tolist()}"
    )

id_col = id_candidates[0]

if id_col != "sample":
    S = S.rename(columns={id_col: "sample"})
    S.to_csv(
        "data/processed/sample_table.csv",
        index=False
    )
    print(f"✅ Renamed '{id_col}' -> 'sample'")
else:
    print("✅ sample column already correct")

print("\nFinal columns:", S.columns.tolist())
print(S.head())
# Out:
# Possible sample-ID columns: ['index']
# ✅ Renamed 'index' -> 'sample'
#
# Final columns: ['sample', 'tumour', 'cohort']
#              sample  tumour     cohort
# 0  TCGA-DD-AAE6-01A       1  TCGA-LIHC
# 1  TCGA-BW-A5NO-01A       1  TCGA-LIHC
# 2  TCGA-DD-AAD0-01A       1  TCGA-LIHC
# 3  TCGA-DD-A1EL-11A       0  TCGA-LIHC
# 4  TCGA-CC-A123-01A       1  TCGA-LIHC

# %%
import pandas as pd

X = pd.read_parquet(
    "data/processed/expression.parquet"
)

C = pd.read_parquet(
    "data/processed/coverage.parquet"
)

S = pd.read_csv(
    "data/processed/sample_table.csv"
)

expr_ids = set(
    X.index.astype(str)
)

label_ids = set(
    S["sample"].astype(str)
)

print("=" * 70)
print("FINAL ALIGNMENT CHECK")
print("=" * 70)

print("Expression :", X.shape)
print("Coverage   :", C.shape)
print("Sample table:", S.shape)

print("\nExact same IDs :", expr_ids == label_ids)
print("Expression-only:", len(expr_ids - label_ids))
print("Label-only     :", len(label_ids - expr_ids))

print("\nCohort × class:")
print(
    pd.crosstab(
        S["cohort"],
        S["tumour"],
        margins=True
    )
)
# Out:
# ...
# FINAL ALIGNMENT CHECK
# ...
# Expression : (2002, 13084)
# Coverage   : (6, 13084)
# Sample table: (2002, 3)
#
# Exact same IDs : True
# Expression-only: 0
# Label-only     : 0
#
# Cohort × class:
# tumour       0     1   All
# cohort
# GSE14520   210   208   418
# GSE25097   241   252   493
# GSE36376   188   230   418
# GSE64041    57    54   111
# GSE76427    48   113   161
# TCGA-LIHC   50   351   401
# All        794  1208  2002

# %%
from pathlib import Path

p = Path("src/02_preprocess.py")
text = p.read_text()

old = '''    sample_table = (
        sample_table
        .set_index("sample")
        .loc[harmonised.index]
        .reset_index()
    )
'''

new = '''    sample_table = (
        sample_table
        .set_index("sample")
        .loc[harmonised.index]
        .reset_index()
    )

    # Guarantee a stable sample-ID column name after index alignment.
    if "sample" not in sample_table.columns:
        first_col = sample_table.columns[0]
        sample_table = sample_table.rename(
            columns={first_col: "sample"}
        )
'''

if old in text:
    p.write_text(text.replace(old, new))
    print("✅ Permanent sample-column fix added.")
elif "Guarantee a stable sample-ID column name" in text:
    print("✅ Fix already present.")
else:
    print("⚠️ Expected block not found.")
# Out:
# ✅ Permanent sample-column fix added.

# %%
from pathlib import Path

p = Path("data/raw/msigdb/c2.cp.v2023.2.Hs.symbols.gmt")

print("Exists:", p.exists())

if p.exists():
    print("Size MB:", round(p.stat().st_size / 1024**2, 2))
# Out:
# Exists: False

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-45b0e23e-54e8-4c85-97bb-dc01aa90df11" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45b0e23e-54e8-4c85-97bb-dc01aa90df11">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from pathlib import Path
import shutil
import yaml

# Current uploaded file
src = Path("/content/c2.cp.v2026.1.Hs.symbols.gmt")

# Destination expected by project structure
dst_dir = Path("data/raw/msigdb")
dst_dir.mkdir(parents=True, exist_ok=True)

dst = dst_dir / "c2.cp.v2026.1.Hs.symbols.gmt"

if src.exists():
    shutil.move(str(src), str(dst))

print("GMT exists:", dst.exists())
print("GMT size:", dst.stat().st_size if dst.exists() else 0)

# Update config
cfg_path = Path("config/config.yaml")
cfg = yaml.safe_load(cfg_path.read_text())

cfg["graph"]["msigdb_collection"] = "c2.cp.v2026.1.Hs.symbols.gmt"

cfg_path.write_text(
    yaml.safe_dump(cfg, sort_keys=False)
)

print(
    "Config MSigDB:",
    cfg["graph"]["msigdb_collection"]
)
# Out:
# GMT exists: False
# GMT size: 0
# Config MSigDB: c2.cp.v2026.1.Hs.symbols.gmt

# %%
from pathlib import Path

matches = list(
    Path("/content").rglob("c2.cp.v2026.1.Hs.symbols.gmt")
)

print("Found files:")
for m in matches:
    print(m)
# Out:
# Found files:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/c2.cp.v2026.1.Hs.symbols.gmt

# %%
from pathlib import Path
import shutil

filename = "c2.cp.v2026.1.Hs.symbols.gmt"

matches = list(Path("/content").rglob(filename))

if not matches:
    raise FileNotFoundError(
        f"{filename} was not found anywhere under /content"
    )

src = matches[0]

dst = Path(
    "/content/GraphOmics_HCC/"
    "GraphOmics_HCC_COMPLETE_RUNNABLE/"
    "code/data/raw/msigdb/"
    + filename
)

dst.parent.mkdir(parents=True, exist_ok=True)

# Avoid trying to move a file onto itself
if src.resolve() != dst.resolve():
    shutil.move(str(src), str(dst))

print("Source found:", src)
print("Final location:", dst)
print("GMT exists:", dst.exists())
print("GMT size:", dst.stat().st_size if dst.exists() else 0)
# Out:
# Source found: /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/c2.cp.v2026.1.Hs.symbols.gmt
# Final location: /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/data/raw/msigdb/c2.cp.v2026.1.Hs.symbols.gmt
# GMT exists: True
# GMT size: 1677390

# %%
import yaml
from pathlib import Path

cfg = yaml.safe_load(
    Path("config/config.yaml").read_text()
)

print(
    "Configured GMT:",
    cfg["graph"]["msigdb_collection"]
)
# Out:
# Configured GMT: c2.cp.v2026.1.Hs.symbols.gmt

# %%
from pathlib import Path

required = [
    "data/processed/expression.parquet",
    "data/raw/string/9606.protein.links.v12.0.txt.gz",
    "data/raw/string/9606.protein.info.v12.0.txt.gz",
    "data/raw/msigdb/c2.cp.v2026.1.Hs.symbols.gmt",
]

for f in required:
    p = Path(f)

    print(
        "✅" if p.exists() else "❌",
        f,
        round(p.stat().st_size / 1024**2, 2)
        if p.exists() else ""
    )
# Out:
# ✅ data/processed/expression.parquet 123.21
# ✅ data/raw/string/9606.protein.links.v12.0.txt.gz 79.31
# ✅ data/raw/string/9606.protein.info.v12.0.txt.gz 1.88
# ✅ data/raw/msigdb/c2.cp.v2026.1.Hs.symbols.gmt 1.6

# %%
# %cd /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code

# !python src/03_build_graph.py \
    --config config/config.yaml
# Out:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code
# vocabulary: 13084 genes
# pathways: 1852 (density 0.00314)
#   reading STRING protein info ...
#   streaming STRING links at combined_score >= 700 ...
# edges: 160742
# {
#   "n_genes": 13084,
#   "n_edges": 160742,
#   "mean_degree": 24.570773463772547,
#   "median_degree": 11.0,
#   "max_degree": 665,
#   "n_isolated": 1690,
#   "clustering_coefficient": null,
#   "largest_component_fraction": 0.8610516661571385,
#   "n_components": 1750,
#   "n_pathways": 1852,
#   "pathway_density": 0.0031428011592151196,
#   "genes_per_pathway_mean": 41.12041091918945,
#   "pathways_per_gene_mean": 5.820467948913574,
#   "gene_pathway_coverage": 0.653546316111281,
#   "string_cutoff": 700,
#   "string_version": "12.0",
#   "msigdb_collection": "c2.cp.v2026.1.Hs.symbols.gmt"
# }
# building degree-preserving rewired control graph ...
#
# written to data/processed/

# %%
import json
import numpy as np
import scipy.sparse as sp
from pathlib import Path

print("=" * 72)
print("REAL GRAPHOMICS-HCC BIOLOGICAL GRAPH")
print("=" * 72)

with open("results/graph_stats.json") as f:
    stats = json.load(f)

print(json.dumps(stats, indent=2))

E = np.load("data/processed/edge_index.npy")
W = np.load("data/processed/edge_weight.npy")
ER = np.load("data/processed/edge_index_rewired.npy")
M = sp.load_npz("data/processed/pathway_mask.npz")

print("\nSaved structures")
print("STRING edge_index :", E.shape)
print("STRING weights    :", W.shape)
print("Rewired edge_index:", ER.shape)
print("Pathway mask      :", M.shape)
print("Memberships       :", M.nnz)

print("\nChecks")
print("Same real/rewired edge count:",
      E.shape[1] == ER.shape[1])

print("Pathways > 0:",
      M.shape[1] > 0)

print("Memberships > 0:",
      M.nnz > 0)
# Out:
# ...
# REAL GRAPHOMICS-HCC BIOLOGICAL GRAPH
# ...
# {
#   "n_genes": 13084,
#   "n_edges": 160742,
#   "mean_degree": 24.570773463772547,
#   "median_degree": 11.0,
#   "max_degree": 665,
#   "n_isolated": 1690,
#   "clustering_coefficient": null,
#   "largest_component_fraction": 0.8610516661571385,
#   "n_components": 1750,
#   "n_pathways": 1852,
#   "pathway_density": 0.0031428011592151196,
#   "genes_per_pathway_mean": 41.12041091918945,
#   "pathways_per_gene_mean": 5.820467948913574,
#   "gene_pathway_coverage": 0.653546316111281,
#   "string_cutoff": 700,
#   "string_version": "12.0",
#   "msigdb_collection": "c2.cp.v2026.1.Hs.symbols.gmt"
# }
#
# Saved structures
# STRING edge_index : (2, 160742)
# STRING weights    : (160742,)
# Rewired edge_index: (2, 160742)
# Pathway mask      : (13084, 1852)
# Memberships       : 76155
#
# Checks
# Same real/rewired edge count: True
# Pathways > 0: True
# Memberships > 0: True

# %%
import json

with open("data/processed/pathway_names.json") as f:
    pathway_names = json.load(f)

print("Total pathways:", len(pathway_names))

print("\nFirst 25 pathways:")
for x in pathway_names[:25]:
    print(x)
# Out:
# Total pathways: 1852
#
# First 25 pathways:
# KEGG_ABC_TRANSPORTERS
# KEGG_ACUTE_MYELOID_LEUKEMIA
# KEGG_ADHERENS_JUNCTION
# KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY
# KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM
# KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION
# KEGG_ALLOGRAFT_REJECTION
# KEGG_ALPHA_LINOLENIC_ACID_METABOLISM
# KEGG_ALZHEIMERS_DISEASE
# KEGG_AMINOACYL_TRNA_BIOSYNTHESIS
# KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM
# KEGG_AMYOTROPHIC_LATERAL_SCLEROSIS_ALS
# KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION
# KEGG_APOPTOSIS
# KEGG_ARACHIDONIC_ACID_METABOLISM
# KEGG_ARGININE_AND_PROLINE_METABOLISM
# KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYOPATHY_ARVC
# KEGG_ASCORBATE_AND_ALDARATE_METABOLISM
# KEGG_ASTHMA
# KEGG_AUTOIMMUNE_THYROID_DISEASE
# KEGG_AXON_GUIDANCE
# KEGG_BASAL_CELL_CARCINOMA
# KEGG_BASAL_TRANSCRIPTION_FACTORS
# KEGG_BASE_EXCISION_REPAIR
# KEGG_BETA_ALANINE_METABOLISM

# %%
import json
import numpy as np
import scipy.sparse as sp

# ---------- Graph statistics ----------
with open("results/graph_stats.json") as f:
    stats = json.load(f)

print("=" * 75)
print("GRAPHOMICS-HCC GRAPH AUDIT")
print("=" * 75)

print("\nGRAPH STATS")
print(json.dumps(stats, indent=2))

# ---------- Saved graph structures ----------
E = np.load("data/processed/edge_index.npy")
W = np.load("data/processed/edge_weight.npy")
ER = np.load("data/processed/edge_index_rewired.npy")
M = sp.load_npz("data/processed/pathway_mask.npz")

with open("data/processed/pathway_names.json") as f:
    pathways = json.load(f)

print("\nSTRUCTURES")
print("edge_index       :", E.shape)
print("edge_weight      :", W.shape)
print("rewired graph    :", ER.shape)
print("pathway_mask     :", M.shape)
print("memberships      :", M.nnz)

# ---------- Pathway source counts ----------
kegg = [p for p in pathways if p.startswith("KEGG_")]
reactome = [p for p in pathways if p.startswith("REACTOME_")]
other = [
    p for p in pathways
    if not p.startswith(("KEGG_", "REACTOME_"))
]

print("\nPATHWAY COUNTS")
print("Total    :", len(pathways))
print("KEGG     :", len(kegg))
print("Reactome :", len(reactome))
print("Other    :", len(other))

# ---------- Basic integrity ----------
print("\nINTEGRITY CHECKS")
print("Pathways > 0              :", len(pathways) > 0)
print("Pathway memberships > 0   :", M.nnz > 0)
print("Real graph edges > 0       :", E.shape[1] > 0)
print("Same real/rewired shape    :", E.shape == ER.shape)
print("Finite STRING weights      :", np.isfinite(W).all())

print("\nFirst 10 Reactome pathways:")
for p in reactome[:10]:
    print(p)
# Out:
# ...
# GRAPHOMICS-HCC GRAPH AUDIT
# ...
#
# GRAPH STATS
# {
#   "n_genes": 13084,
#   "n_edges": 160742,
#   "mean_degree": 24.570773463772547,
#   "median_degree": 11.0,
#   "max_degree": 665,
#   "n_isolated": 1690,
#   "clustering_coefficient": null,
#   "largest_component_fraction": 0.8610516661571385,
#   "n_components": 1750,
#   "n_pathways": 1852,
#   "pathway_density": 0.0031428011592151196,
#   "genes_per_pathway_mean": 41.12041091918945,
#   "pathways_per_gene_mean": 5.820467948913574,
#   "gene_pathway_coverage": 0.653546316111281,
#   "string_cutoff": 700,
#   "string_version": "12.0",
#   "msigdb_collection": "c2.cp.v2026.1.Hs.symbols.gmt"
# }
#
# STRUCTURES
# edge_index       : (2, 160742)
# edge_weight      : (160742,)
# rewired graph    : (2, 160742)
# pathway_mask     : (13084, 1852)
# memberships      : 76155
#
# PATHWAY COUNTS
# Total    : 1852
# KEGG     : 531
# Reactome : 1321
# Other    : 0
#
# INTEGRITY CHECKS
# Pathways > 0              : True
# ...

# %%
import pandas as pd
import scipy.sparse as sp

X = pd.read_parquet("data/processed/expression.parquet")
M = sp.load_npz("data/processed/pathway_mask.npz")

print("Expression genes:", X.shape[1])
print("Pathway-mask rows:", M.shape[0])

print(
    "Gene dimensions agree:",
    X.shape[1] == M.shape[0]
)
# Out:
# Expression genes: 13084
# Pathway-mask rows: 13084
# Gene dimensions agree: True

# %%
import json
import numpy as np
import scipy.sparse as sp

with open("results/graph_stats.json") as f:
    stats = json.load(f)

E = np.load("data/processed/edge_index.npy")
W = np.load("data/processed/edge_weight.npy")
ER = np.load("data/processed/edge_index_rewired.npy")
M = sp.load_npz("data/processed/pathway_mask.npz")

with open("data/processed/pathway_names.json") as f:
    pathways = json.load(f)

kegg = [p for p in pathways if p.startswith("KEGG_")]
reactome = [p for p in pathways if p.startswith("REACTOME_")]

print("GRAPH STATS")
print(json.dumps(stats, indent=2))

print("\nSTRUCTURES")
print("edge_index:", E.shape)
print("edge_weight:", W.shape)
print("rewired:", ER.shape)
print("pathway_mask:", M.shape)
print("memberships:", M.nnz)

print("\nPATHWAYS")
print("Total:", len(pathways))
print("KEGG:", len(kegg))
print("Reactome:", len(reactome))

print("\nCHECKS")
print("Edges > 0:", E.shape[1] > 0)
print("Same real/rewired shape:", E.shape == ER.shape)
print("Finite weights:", np.isfinite(W).all())
print("Memberships > 0:", M.nnz > 0)
# Out:
# GRAPH STATS
# {
#   "n_genes": 13084,
#   "n_edges": 160742,
#   "mean_degree": 24.570773463772547,
#   "median_degree": 11.0,
#   "max_degree": 665,
#   "n_isolated": 1690,
#   "clustering_coefficient": null,
#   "largest_component_fraction": 0.8610516661571385,
#   "n_components": 1750,
#   "n_pathways": 1852,
#   "pathway_density": 0.0031428011592151196,
#   "genes_per_pathway_mean": 41.12041091918945,
#   "pathways_per_gene_mean": 5.820467948913574,
#   "gene_pathway_coverage": 0.653546316111281,
#   "string_cutoff": 700,
#   "string_version": "12.0",
#   "msigdb_collection": "c2.cp.v2026.1.Hs.symbols.gmt"
# }
#
# STRUCTURES
# edge_index: (2, 160742)
# edge_weight: (160742,)
# rewired: (2, 160742)
# pathway_mask: (13084, 1852)
# memberships: 76155
#
# PATHWAYS
# Total: 1852
# KEGG: 531
# Reactome: 1321
#
# CHECKS
# Edges > 0: True
# Same real/rewired shape: True
# Finite weights: True
# Memberships > 0: True

# %%
import yaml
import torch
from pathlib import Path

cfg = yaml.safe_load(
    Path("config/config.yaml").read_text()
)

print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")

print("\nCONFIG")
print("Development cohort:", cfg["cohorts"]["development"])
print("External cohorts:", cfg["cohorts"]["external"])
print("MSigDB:", cfg["graph"]["msigdb_collection"])
print("STRING cutoff:", cfg["graph"]["string_cutoff"])
print("Hidden dim:", cfg["model"]["hidden_dim"])
print("Graph layers:", cfg["model"]["n_layers"])
print("Dropout:", cfg["model"]["dropout"])
print("Use hierarchy:", cfg["model"]["use_hierarchy"])
print("Use pathway mask:", cfg["model"]["use_mask"])
print("Outer folds:", cfg["train"]["outer_folds"])
print("Max epochs:", cfg["train"]["max_epochs"])
print("Patience:", cfg["train"]["patience"])
# Out:
# CUDA available: True
# GPU: Tesla T4
#
# CONFIG
# Development cohort: TCGA-LIHC
# External cohorts: ['GSE14520', 'GSE25097', 'GSE36376', 'GSE76427', 'GSE64041']
# MSigDB: c2.cp.v2026.1.Hs.symbols.gmt
# STRING cutoff: 700
# Hidden dim: 64
# Graph layers: 2
# Dropout: 0.3
# Use hierarchy: True
# Use pathway mask: True
# Outer folds: 5
# Max epochs: 200
# Patience: 20

# %%
from pathlib import Path
import yaml

cfg_path = Path("config/config.yaml")

cfg = yaml.safe_load(cfg_path.read_text())

cfg["model"]["use_hierarchy"] = False

cfg_path.write_text(
    yaml.safe_dump(cfg, sort_keys=False)
)

print("use_hierarchy =", cfg["model"]["use_hierarchy"])
# Out:
# use_hierarchy = False

# %%
import yaml
import torch
from pathlib import Path

cfg = yaml.safe_load(
    Path("config/config.yaml").read_text()
)

print("CUDA:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))

print("\nDevelopment:", cfg["cohorts"]["development"])
print("External:", cfg["cohorts"]["external"])
print("MSigDB:", cfg["graph"]["msigdb_collection"])
print("STRING cutoff:", cfg["graph"]["string_cutoff"])

print("\nMODEL")
print("Hidden dim:", cfg["model"]["hidden_dim"])
print("Layers:", cfg["model"]["n_layers"])
print("Dropout:", cfg["model"]["dropout"])
print("Hierarchy:", cfg["model"]["use_hierarchy"])
print("Pathway mask:", cfg["model"]["use_mask"])

print("\nTRAINING")
print("Batch size:", cfg["train"]["batch_size"])
print("Epochs:", cfg["train"]["max_epochs"])
print("Patience:", cfg["train"]["patience"])
print("Outer folds:", cfg["train"]["outer_folds"])
# Out:
# CUDA: True
# GPU: Tesla T4
#
# Development: TCGA-LIHC
# External: ['GSE14520', 'GSE25097', 'GSE36376', 'GSE76427', 'GSE64041']
# MSigDB: c2.cp.v2026.1.Hs.symbols.gmt
# STRING cutoff: 700
#
# MODEL
# Hidden dim: 64
# Layers: 2
# Dropout: 0.3
# Hierarchy: False
# Pathway mask: True
#
# TRAINING
# Batch size: 32
# Epochs: 200
# Patience: 20
# Outer folds: 5

# %%
# %cd /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code

# !python src/04_train_eval.py \
    --config config/config.yaml \
    --mode main \
    --device cuda
# Out:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code
# device: cuda
#
# === GraphOmics-HCC ===
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/model.py:51: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:760.)
#   return torch.sparse_coo_tensor(idx, torch.tensor(vals), (n_nodes, n_nodes)).coalesce()
# development cohort TCGA-LIHC: 401 samples (351 tumour)
#   outer fold 1/5
#     inner-validation AUROC 0.9958
#   outer fold 2/5
#     inner-validation AUROC 0.9314
#   outer fold 3/5
#     inner-validation AUROC 0.9936
#   outer fold 4/5
#     inner-validation AUROC 0.9914
#   outer fold 5/5
# ...

# %%
import json

with open("results/metrics_raw.json") as f:
    r = json.load(f)

g = r["graphomics"]

print("=" * 75)
print("REAL GRAPHOMICS-HCC RESULTS")
print("=" * 75)

print("\nParameters:", g["n_parameters"])
print("Training time:", round(g["train_seconds"], 2), "seconds")
print("Fixed threshold:", round(g["threshold"], 6))

print("\nTCGA-LIHC OUT-OF-FOLD")
for key, value in g["internal"].items():
    if isinstance(value, (int, float)):
        print(f"{key}: {value}")

print("\nEXTERNAL VALIDATION")
for cohort, m in g["external"].items():
    print("\n", cohort)
    for key, value in m.items():
        if isinstance(value, (int, float)):
            print(f"  {key}: {value}")

print("\nMean external AUROC:",
      g.get("external_mean_auroc"))

print("External AUROC range:",
      g.get("external_auroc_range"))

print("Internal-external gap:",
      g.get("internal_external_gap"))
# Out:
# ...
# REAL GRAPHOMICS-HCC RESULTS
# ...
#
# Parameters: 24244298
# Training time: 220.93 seconds
# Fixed threshold: 0.501063
#
# TCGA-LIHC OUT-OF-FOLD
# auroc: 0.5958974358974358
# auprc: 0.9159435650467177
# sensitivity: 0.5954415954415955
# specificity: 0.6
# balanced_accuracy: 0.5977207977207977
# f1: 0.7206896551724138
# mcc: 0.13045886476071694
# brier: 0.24950948081769028
# n: 401
# n_pos: 351
# auroc_ci_low: 0.511181627063563
# auroc_ci_high: 0.6834216526901064
# calibration_slope: 0.018267909524717265
# calibration_intercept: 1.9486981133573378
# ece: 0.3744171879386664
# mce: 0.49892155826091766
#
# EXTERNAL VALIDATION
#
#  GSE14520
#   auroc: 0.9144803113553114
#   auprc: 0.9181407166129673
#   sensitivity: 0.0
#   specificity: 1.0
#   balanced_accuracy: 0.5
#   f1: 0.0
#   mcc: 0.0
#   brier: 0.2500028878694301
#   n: 418
#   n_pos: 208
#   auroc_ci_low: 0.8868512566709911
#   auroc_ci_high: 0.9403874796183497
#   calibration_slope: 234335.8682880042
# ...

# %%
import json
import pandas as pd
import numpy as np

with open("results/metrics_raw.json") as f:
    r = json.load(f)

g = r["graphomics"]
thr = g["threshold"]

pred = pd.read_csv(
    "results/predictions_graphomics.csv"
)

print("=" * 78)
print("GRAPHOMICS-HCC SCORE AUDIT")
print("=" * 78)

print("\nFIXED DEVELOPMENT THRESHOLD")
print("threshold =", thr)

print("\nINTERNAL TCGA METRICS")
for k, v in g["internal"].items():
    if isinstance(v, (int, float)):
        print(f"{k}: {v}")

print("\nPROBABILITY DISTRIBUTIONS")

for cohort in pred["cohort"].unique():

    d = pred[pred["cohort"] == cohort].copy()

    print("\n" + "=" * 60)
    print(cohort)
    print("=" * 60)

    print("n =", len(d))

    print(
        "p min / q05 / q25 / median / q75 / q95 / max:"
    )

    print(
        np.quantile(
            d["p"],
            [0, .05, .25, .50, .75, .95, 1]
        )
    )

    print(
        "mean p overall =",
        d["p"].mean()
    )

    print(
        "mean p non-tumour =",
        d.loc[d["y"] == 0, "p"].mean()
    )

    print(
        "mean p tumour =",
        d.loc[d["y"] == 1, "p"].mean()
    )

    print(
        "fraction >= fixed threshold =",
        (d["p"] >= thr).mean()
    )
# Out:
# ...
# GRAPHOMICS-HCC SCORE AUDIT
# ...
#
# FIXED DEVELOPMENT THRESHOLD
# threshold = 0.5010629892349243
#
# INTERNAL TCGA METRICS
# auroc: 0.5958974358974358
# auprc: 0.9159435650467177
# sensitivity: 0.5954415954415955
# specificity: 0.6
# balanced_accuracy: 0.5977207977207977
# f1: 0.7206896551724138
# mcc: 0.13045886476071694
# brier: 0.24950948081769028
# n: 401
# n_pos: 351
# auroc_ci_low: 0.511181627063563
# auroc_ci_high: 0.6834216526901064
# calibration_slope: 0.018267909524717265
# calibration_intercept: 1.9486981133573378
# ece: 0.3744171879386664
# mce: 0.49892155826091766
#
# PROBABILITY DISTRIBUTIONS
#
# ...
# TCGA-LIHC
# ...
# n = 401
# p min / q05 / q25 / median / q75 / q95 / max:
# [0.48178139 0.48181066 0.49328735 0.50107461 0.50564343 0.52265149
#  0.52265406]
# mean p overall = 0.500894532759588
# mean p non-tumour = 0.5008828175067902
# mean p tumour = 0.5008962015990178
# fraction >= fixed threshold = 0.571072319201995
#
# ...
# GSE14520
# ...
# n = 418
# ...

# %%
import json

with open("results/training_history.json") as f:
    histories = json.load(f)

print("FOLD TRAINING SUMMARY")

for i, hist in enumerate(histories, start=1):

    best = max(
        hist,
        key=lambda x: x["val_auroc"]
    )

    print(
        f"Fold {i}: "
        f"best AUROC={best['val_auroc']:.4f}, "
        f"best epoch={best['epoch']}, "
        f"epochs run={len(hist)}"
    )
# Out:
# FOLD TRAINING SUMMARY
# Fold 1: best AUROC=0.9958, best epoch=1, epochs run=22
# Fold 2: best AUROC=0.9314, best epoch=1, epochs run=22
# Fold 3: best AUROC=0.9936, best epoch=1, epochs run=22
# Fold 4: best AUROC=0.9914, best epoch=2, epochs run=23
# Fold 5: best AUROC=0.9850, best epoch=2, epochs run=23

# %%
from pathlib import Path
import shutil

backup = Path("results/diagnostic_run_before_scale_fix")
backup.mkdir(parents=True, exist_ok=True)

for f in [
    "metrics_raw.json",
    "predictions_graphomics.csv",
    "training_history.json"
]:
    src = Path("results") / f
    if src.exists():
        shutil.copy2(src, backup / f)

print("✅ Current diagnostic results backed up")
# Out:
# ✅ Current diagnostic results backed up

# %%
from pathlib import Path

p = Path("src/model.py")
text = p.read_text()

old_l1 = '''    def l1(self) -> torch.Tensor:
        return (self.weight * self.mask).abs().sum()
'''

new_l1 = '''    def l1(self) -> torch.Tensor:
        # Mean absolute weight over biologically active memberships only.
        # This makes the regularisation strength independent of pathway-mask size.
        active = (self.weight * self.mask).abs()
        return active.sum() / self.mask.sum().clamp(min=1.0)
'''

old_smooth = '''    B, G = z.shape
    flat = z.t()                                   # (G, B)
    az = torch.sparse.mm(A, flat).t()              # (B, G)
    return ((z * (z - az)).sum(dim=1)).mean()
'''

new_smooth = '''    B, G = z.shape
    flat = z.t()                                   # (G, B)
    az = torch.sparse.mm(A, flat).t()              # (B, G)

    # Mean Dirichlet energy per gene rather than a raw sum over all genes.
    # This prevents regularisation magnitude from growing with graph size.
    return ((z * (z - az)).sum(dim=1) / G).mean()
'''

changed = False

if old_l1 in text:
    text = text.replace(old_l1, new_l1)
    changed = True
    print("✅ L1 regulariser normalized")
elif "regularisation strength independent of pathway-mask size" in text:
    print("✅ L1 already normalized")
else:
    print("⚠️ L1 block not found")

if old_smooth in text:
    text = text.replace(old_smooth, new_smooth)
    changed = True
    print("✅ Graph smoothness normalized")
elif "Mean Dirichlet energy per gene" in text:
    print("✅ Graph smoothness already normalized")
else:
    print("⚠️ Smoothness block not found")

if changed:
    p.write_text(text)
# Out:
# ✅ L1 regulariser normalized
# ✅ Graph smoothness normalized

# %%
# !grep -n -A8 "def l1" src/model.py
# !grep -n -A12 "def graph_smoothness" src/model.py
# Out:
# 166:    def l1(self) -> torch.Tensor:
# 167-        # Mean absolute weight over biologically active memberships only.
# 168-        # This makes the regularisation strength independent of pathway-mask size.
# 169-        active = (self.weight * self.mask).abs()
# 170-        return active.sum() / self.mask.sum().clamp(min=1.0)
# 171-
# 172-
# 173-class GradientReversal(torch.autograd.Function):
# 174-    """Used only for the optional LOCO domain-confusion term."""
# 278:def graph_smoothness(z: torch.Tensor, A: torch.Tensor) -> torch.Tensor:
# 279-    """Dirichlet energy z^T L z, with L = I - Â, on the fixed graph.
# 280-
# 281-    Penalises gene scores that swing sharply between directly interacting
# 282-    partners. It regularises the *explanation*, not the prediction: two proteins
# 283-    in the same complex should not receive opposite credit for the same call
# 284-    unless the data really demand it.
# 285-    """
# 286-    B, G = z.shape
# ...

# %%
# !python -m pytest tests/ -q
# Out:
# ........................                                                 [100%]
# =============================== warnings summary ===============================
# tests/test_corrected_controls.py::test_gnnexplainer_masked_adjacency_is_differentiable
#   /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/05_explain.py:65: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:760.)
#     return torch.sparse_coo_tensor(torch.stack([src, dst]), vals,
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 24 passed, 1 warning in 7.08s

# %%
# !python src/04_train_eval.py \
    --config config/config.yaml \
    --mode main \
    --device cuda
# Out:
# device: cuda
#
# === GraphOmics-HCC ===
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/model.py:51: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:760.)
#   return torch.sparse_coo_tensor(idx, torch.tensor(vals), (n_nodes, n_nodes)).coalesce()
# development cohort TCGA-LIHC: 401 samples (351 tumour)
#   outer fold 1/5
#     inner-validation AUROC 1.0000
#   outer fold 2/5
#     inner-validation AUROC 1.0000
#   outer fold 3/5
#     inner-validation AUROC 0.9986
#   outer fold 4/5
#     inner-validation AUROC 1.0000
#   outer fold 5/5
#     inner-validation AUROC 1.0000
# ...

# %%
import json
import pandas as pd
import numpy as np

with open("results/metrics_raw.json") as f:
    r = json.load(f)

g = r["graphomics"]

print("Internal AUROC:", g["internal"]["auroc"])
print("Threshold:", g["threshold"])
print("Mean external AUROC:", g["external_mean_auroc"])

pred = pd.read_csv("results/predictions_graphomics.csv")

for cohort in pred["cohort"].unique():
    d = pred[pred["cohort"] == cohort]

    print(
        cohort,
        "min =", round(d["p"].min(), 6),
        "median =", round(d["p"].median(), 6),
        "max =", round(d["p"].max(), 6),
        "mean_neg =", round(d.loc[d["y"] == 0, "p"].mean(), 6),
        "mean_pos =", round(d.loc[d["y"] == 1, "p"].mean(), 6)
    )
# Out:
# Internal AUROC: 0.8707122507122508
# Threshold: 0.4898492097854614
# Mean external AUROC: 0.9822774281147787
# TCGA-LIHC min = 0.002928 median = 0.530193 max = 0.999988 mean_neg = 0.297162 mean_pos = 0.670835
# GSE14520 min = 0.316799 median = 0.514845 max = 0.696777 mean_neg = 0.385503 mean_pos = 0.683314
# GSE25097 min = 0.293403 median = 0.507199 max = 0.698051 mean_neg = 0.303654 mean_pos = 0.672287
# GSE36376 min = 0.304651 median = 0.646195 max = 0.698641 mean_neg = 0.331048 mean_pos = 0.673923
# GSE76427 min = 0.3218 median = 0.693176 max = 0.698931 mean_neg = 0.440923 mean_pos = 0.682106
# GSE64041 min = 0.29859 median = 0.344026 max = 0.69488 mean_neg = 0.318018 mean_pos = 0.562867

# %%
from pathlib import Path
import re

p = Path("src/04_train_eval.py")

# Backup current working version
backup = Path("src/04_train_eval_before_nested_fix.py")
if not backup.exists():
    backup.write_text(p.read_text())

text = p.read_text()

if "untouched outer-fold OOF CV" in text:
    print("✅ Nested evaluation patch already applied.")

else:
    # ------------------------------------------------------------
    # Imports
    # ------------------------------------------------------------
    text = text.replace(
        "from sklearn.model_selection import StratifiedKFold",
        "from sklearn.model_selection import StratifiedKFold, train_test_split"
    )

    if "from sklearn.linear_model import LogisticRegression" not in text:
        text = text.replace(
            "from sklearn.model_selection import StratifiedKFold, train_test_split",
            "from sklearn.model_selection import StratifiedKFold, train_test_split\n"
            "from sklearn.linear_model import LogisticRegression\n"
            "from sklearn.metrics import roc_auc_score"
        )

    # ------------------------------------------------------------
    # Calibration helpers
    # ------------------------------------------------------------
    old = '''def ensemble_predict(models, X, A, edge_index, device):
    return np.mean([predict(m, X, A, edge_index, device) for m in models], axis=0)
'''

    new = '''def ensemble_predict(models, X, A, edge_index, device):
    return np.mean(
        [predict(m, X, A, edge_index, device) for m in models],
        axis=0
    )


def fit_platt_scaler(y, p):
    """Development-only Platt scaling."""
    p = np.clip(
        np.asarray(p, dtype=float),
        1e-6,
        1 - 1e-6
    )

    z = np.log(
        p / (1 - p)
    ).reshape(-1, 1)

    lr = LogisticRegression(
        C=1.0,
        solver="lbfgs",
        max_iter=2000
    )

    lr.fit(
        z,
        np.asarray(y, dtype=int)
    )

    return {
        "intercept": float(lr.intercept_[0]),
        "slope": float(lr.coef_[0][0]),
    }


def apply_platt_scaler(p, cal):
    p = np.clip(
        np.asarray(p, dtype=float),
        1e-6,
        1 - 1e-6
    )

    z = np.log(p / (1 - p))

    eta = (
        cal["intercept"]
        + cal["slope"] * z
    )

    eta = np.clip(
        eta,
        -40,
        40
    )

    return 1.0 / (
        1.0 + np.exp(-eta)
    )


def calibrated_ensemble_predict(
    models,
    calibrators,
    X,
    A,
    edge_index,
    device
):
    probs = []

    for model, cal in zip(
        models,
        calibrators
    ):
        raw = predict(
            model,
            X,
            A,
            edge_index,
            device
        )

        probs.append(
            apply_platt_scaler(
                raw,
                cal
            )
        )

    return np.mean(
        probs,
        axis=0
    )
'''

    if old not in text:
        raise RuntimeError(
            "Could not locate ensemble_predict block."
        )

    text = text.replace(old, new)

    # ------------------------------------------------------------
    # Replace run_main
    # ------------------------------------------------------------
    start = text.index(
        "def run_main(cfg, device, save_artifacts=True):"
    )

    end = text.index(
        "\n\n# --------------------------------------------------------------------------\n\n\ndef run_baselines",
        start
    )

    new_run_main = r'''def run_main(cfg, device, save_artifacts=True):
    X, samples, coverage, edge_index, edge_weight, M, H = load_inputs(cfg)

    Xt = to_tensor(
        X,
        samples,
        coverage,
        cfg.get(
            "features",
            "expression_plus_coverage"
        )
    )

    y = samples["tumour"].values.astype(int)
    cohort = samples["cohort"].values

    dev = cfg["cohorts"]["development"]

    A = normalise_adjacency(
        edge_index,
        Xt.shape[1],
        edge_weight
    )

    dev_idx = np.flatnonzero(
        cohort == dev
    )

    print(
        f"development cohort {dev}: "
        f"{len(dev_idx)} samples "
        f"({y[dev_idx].sum()} tumour)"
    )

    # ---------------------------------------------------------
    # STRICT OUTER CV
    # Outer validation fold is never used for early stopping.
    # ---------------------------------------------------------
    outer = StratifiedKFold(
        cfg["train"]["outer_folds"],
        shuffle=True,
        random_state=cfg["seed"]
    )

    inner_frac = float(
        cfg["train"].get(
            "inner_val_fraction",
            0.20
        )
    )

    fold_models = []
    fold_calibrators = []

    oof_pred = []
    oof_true = []
    oof_sample_idx = []
    histories = []

    t0 = time.time()

    for k, (tr, va) in enumerate(
        outer.split(
            dev_idx,
            y[dev_idx]
        )
    ):

        print(
            f"  outer fold "
            f"{k + 1}/"
            f"{cfg['train']['outer_folds']}"
        )

        outer_tr_i = dev_idx[tr]
        va_i = dev_idx[va]

        # Inner split only from outer-training samples
        fit_i, inner_i = train_test_split(
            outer_tr_i,
            test_size=inner_frac,
            stratify=y[outer_tr_i],
            random_state=(
                cfg["seed"]
                + 1000
                + k
            )
        )

        model, inner_auc, hist = train_one(
            Xt[fit_i],
            y[fit_i],

            Xt[inner_i],
            y[inner_i],

            A,
            edge_index,
            M,
            H,
            cfg,

            cfg["seed"] + k,
            device
        )

        # ---------------------------------------------
        # Development-only probability calibration
        # ---------------------------------------------
        p_inner_raw = predict(
            model,
            Xt[inner_i],
            A,
            edge_index,
            device
        )

        cal = fit_platt_scaler(
            y[inner_i],
            p_inner_raw
        )

        # ---------------------------------------------
        # Untouched outer hold-out
        # ---------------------------------------------
        p_va_raw = predict(
            model,
            Xt[va_i],
            A,
            edge_index,
            device
        )

        p_va = apply_platt_scaler(
            p_va_raw,
            cal
        )

        outer_auc = roc_auc_score(
            y[va_i],
            p_va
        )

        oof_pred.append(p_va)
        oof_true.append(y[va_i])
        oof_sample_idx.append(va_i)

        fold_models.append(model)
        fold_calibrators.append(cal)
        histories.append(hist)

        print(
            f"    inner early-stop AUROC "
            f"{inner_auc:.4f} | "
            f"untouched outer AUROC "
            f"{outer_auc:.4f} | "
            f"Platt slope "
            f"{cal['slope']:.3f}"
        )

    # ---------------------------------------------------------
    # Pool untouched outer-fold predictions
    # ---------------------------------------------------------
    oof_pred = np.concatenate(
        oof_pred
    )

    oof_true = np.concatenate(
        oof_true
    )

    threshold = float(
        youden_threshold(
            oof_true,
            oof_pred
        )
    )

    print(
        f"  operating threshold fixed at "
        f"{threshold:.4f} from pooled "
        f"calibrated development OOF "
        f"predictions"
    )

    results = {

        "threshold": threshold,

        "evaluation_protocol":
            "5-fold stratified outer CV; "
            "inner development split for "
            "early stopping and Platt scaling; "
            "pooled calibrated OOF threshold; "
            "frozen calibrated fold ensemble "
            "for external validation",

        "internal": evaluate(
            oof_true,
            oof_pred,
            threshold,
            n_boot=cfg["eval"]["n_bootstrap"],
            label=(
                f"{dev} "
                "(untouched outer-fold OOF CV)"
            )
        ),

        "external": {},

        "predictions": [],

        "fold_calibration":
            fold_calibrators,

        "n_parameters":
            int(
                fold_models[0]
                .n_parameters()
            ),

        "train_seconds":
            float(
                time.time() - t0
            ),
    }

    print(
        f"  internal AUROC "
        f"{results['internal']['auroc']:.4f}"
    )

    # ---------------------------------------------------------
    # Save development OOF predictions
    # ---------------------------------------------------------
    oof_samples = np.concatenate(
        oof_sample_idx
    )

    for s, pi, yi in zip(
        X.index[oof_samples],
        oof_pred,
        oof_true
    ):
        results["predictions"].append(
            {
                "sample": s,
                "cohort": dev,
                "model": "GraphOmics-HCC",
                "p": float(pi),
                "y": int(yi),
                "split":
                    "development_outer_oof",
            }
        )

    # ---------------------------------------------------------
    # Frozen external validation
    # ---------------------------------------------------------
    print(
        "\nexternal validation "
        "(frozen calibrated ensemble, "
        "no refitting)"
    )

    for c in cfg["cohorts"]["external"]:

        idx = np.flatnonzero(
            cohort == c
        )

        if len(idx) == 0:
            print(
                f"  {c}: absent, skipped"
            )
            continue

        if len(np.unique(y[idx])) < 2:
            print(
                f"  {c}: single class, skipped"
            )
            continue

        p = calibrated_ensemble_predict(
            fold_models,
            fold_calibrators,
            Xt[idx],
            A,
            edge_index,
            device
        )

        results["external"][c] = evaluate(
            y[idx],
            p,
            threshold,
            n_boot=(
                cfg["eval"]["n_bootstrap"]
            ),
            label=c
        )

        print(
            f"  {c}: AUROC "
            f"{results['external'][c]['auroc']:.4f} "
            f"("
            f"{results['external'][c]['auroc_ci_low']:.3f}"
            f"–"
            f"{results['external'][c]['auroc_ci_high']:.3f}"
            f"), n={len(idx)}"
        )

        for s, pi, yi in zip(
            X.index[idx],
            p,
            y[idx]
        ):
            results["predictions"].append(
                {
                    "sample": s,
                    "cohort": c,
                    "model":
                        "GraphOmics-HCC",
                    "p": float(pi),
                    "y": int(yi),
                    "split": "external",
                }
            )

    ext = [
        v["auroc"]
        for v in
        results["external"].values()
    ]

    if ext:

        results["external_mean_auroc"] = (
            float(np.mean(ext))
        )

        results["external_auroc_range"] = [
            float(min(ext)),
            float(max(ext))
        ]

        results[
            "internal_external_gap"
        ] = float(
            results["internal"]["auroc"]
            - np.mean(ext)
        )

        print(
            f"\n  mean external AUROC "
            f"{np.mean(ext):.4f} "
            f"(internal-external gap "
            f"{results['internal_external_gap']:+.4f})"
        )

    # ---------------------------------------------------------
    # Save reproducibility artifacts
    # ---------------------------------------------------------
    if save_artifacts:

        torch.save(
            [
                m.state_dict()
                for m in fold_models
            ],
            os.path.join(
                cfg["paths"]["results"],
                "model_weights.pt"
            )
        )

        save_json(
            histories,
            os.path.join(
                cfg["paths"]["results"],
                "training_history.json"
            )
        )

        save_json(
            fold_calibrators,
            os.path.join(
                cfg["paths"]["results"],
                "fold_calibration.json"
            )
        )

    return results, (
        X,
        samples,
        Xt,
        y,
        cohort,
        A,
        edge_index,
        M,
        H,
        fold_models,
        threshold
    )
'''

    text = (
        text[:start]
        + new_run_main
        + text[end:]
    )

    p.write_text(text)

    print("✅ Strict nested/outer-CV evaluation patch applied.")
    print("✅ External-label leakage: none.")
    print("✅ Fold calibration fitted on development data only.")
# Out:
# ✅ Strict nested/outer-CV evaluation patch applied.
# ✅ External-label leakage: none.
# ✅ Fold calibration fitted on development data only.

# %%
from pathlib import Path
import yaml

p = Path("config/config.yaml")
cfg = yaml.safe_load(p.read_text())

cfg["train"]["inner_val_fraction"] = 0.20

p.write_text(
    yaml.safe_dump(
        cfg,
        sort_keys=False
    )
)

print(
    "inner_val_fraction =",
    cfg["train"]["inner_val_fraction"]
)
# Out:
# inner_val_fraction = 0.2

# %%
# !python -m pytest tests/ -q
# Out:
# ........................                                                 [100%]
# =============================== warnings summary ===============================
# tests/test_corrected_controls.py::test_gnnexplainer_masked_adjacency_is_differentiable
#   /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/05_explain.py:65: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:760.)
#     return torch.sparse_coo_tensor(torch.stack([src, dst]), vals,
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 24 passed, 1 warning in 7.53s

# %%
from pathlib import Path

p = Path("src/04_train_eval.py")
text = p.read_text()

# Add LogisticRegression import if missing
if "from sklearn.linear_model import LogisticRegression" not in text:
    lines = text.splitlines()

    # Insert near the other sklearn imports
    insert_at = 0
    for i, line in enumerate(lines):
        if line.startswith("from sklearn") or line.startswith("import sklearn"):
            insert_at = i + 1

    lines.insert(
        insert_at,
        "from sklearn.linear_model import LogisticRegression"
    )

    text = "\n".join(lines) + "\n"
    p.write_text(text)

    print("✅ LogisticRegression import added.")
else:
    print("✅ LogisticRegression already imported.")
# Out:
# ✅ LogisticRegression already imported.

# %%
from pathlib import Path

p = Path("src/04_train_eval.py")
text = p.read_text()

if "roc_auc_score" not in text.split("def run_main")[0]:
    lines = text.splitlines()

    insert_at = 0
    for i, line in enumerate(lines):
        if line.startswith("from sklearn") or line.startswith("import sklearn"):
            insert_at = i + 1

    lines.insert(
        insert_at,
        "from sklearn.metrics import roc_auc_score"
    )

    p.write_text("\n".join(lines) + "\n")
    print("✅ roc_auc_score import added.")
else:
    print("✅ roc_auc_score already imported.")
# Out:
# ✅ roc_auc_score already imported.

# %%
# !grep -n "LogisticRegression\|roc_auc_score" src/04_train_eval.py | head -10
# Out:
# 144:        from sklearn.metrics import roc_auc_score
# 145:        auc = roc_auc_score(yva, p) if len(np.unique(yva)) > 1 else np.nan
# 191:    lr = LogisticRegression(
# 418:        outer_auc = roc_auc_score(
# 693:    from sklearn.linear_model import LogisticRegression
# 703:        "L1 logistic": LogisticRegression(penalty="l1", solver="liblinear", C=0.1, max_iter=bcfg.get("logreg_max_iter", 2000)),
# 704:        "Elastic net": LogisticRegression(penalty="elasticnet", solver="saga", l1_ratio=0.5,

# %%
# !python -m py_compile src/04_train_eval.py

# %%
from pathlib import Path

p = Path(
    "/content/GraphOmics_HCC/"
    "GraphOmics_HCC_COMPLETE_RUNNABLE/"
    "code/src/04_train_eval.py"
)

assert p.exists(), f"File not found: {p}"

text = p.read_text()

# --------------------------------------------------
# Force LogisticRegression import INSIDE the function
# --------------------------------------------------
old = '''def fit_platt_scaler(y, p):
    """Development-only Platt scaling."""
'''

new = '''def fit_platt_scaler(y, p):
    """Development-only Platt scaling."""
    from sklearn.linear_model import LogisticRegression
'''

if old in text:
    text = text.replace(old, new, 1)
    print("✅ Added local LogisticRegression import.")
elif '''def fit_platt_scaler(y, p):
    """Development-only Platt scaling."""
    from sklearn.linear_model import LogisticRegression
''' in text:
    print("✅ Local LogisticRegression import already present.")
else:
    raise RuntimeError("Could not locate fit_platt_scaler().")

# --------------------------------------------------
# Force roc_auc_score import inside run_main as well
# --------------------------------------------------
old2 = '''def run_main(cfg, device, save_artifacts=True):
    X, samples, coverage, edge_index, edge_weight, M, H = load_inputs(cfg)
'''

new2 = '''def run_main(cfg, device, save_artifacts=True):
    from sklearn.metrics import roc_auc_score

    X, samples, coverage, edge_index, edge_weight, M, H = load_inputs(cfg)
'''

if old2 in text:
    text = text.replace(old2, new2, 1)
    print("✅ Added local roc_auc_score import.")
elif '''def run_main(cfg, device, save_artifacts=True):
    from sklearn.metrics import roc_auc_score
''' in text:
    print("✅ Local roc_auc_score import already present.")

p.write_text(text)

print("\nPatched file:")
print(p)
# Out:
# ✅ Added local LogisticRegression import.
# ✅ Added local roc_auc_score import.
#
# Patched file:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/04_train_eval.py

# %%
# !grep -n -A8 "def fit_platt_scaler" \
/content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/04_train_eval.py
# Out:
# 179:def fit_platt_scaler(y, p):
# 180-    """Development-only Platt scaling."""
# 181-    from sklearn.linear_model import LogisticRegression
# 182-    p = np.clip(
# 183-        np.asarray(p, dtype=float),
# 184-        1e-6,
# 185-        1 - 1e-6
# 186-    )
# 187-

# %%
# !grep -n -A5 "def run_main" \
/content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/04_train_eval.py
# Out:
# 281:def run_main(cfg, device, save_artifacts=True):
# 282-    from sklearn.metrics import roc_auc_score
# 283-
# 284-    X, samples, coverage, edge_index, edge_weight, M, H = load_inputs(cfg)
# 285-
# 286-    Xt = to_tensor(

# %%
# !python -m py_compile \
/content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/04_train_eval.py

print("✅ Compile completed")
# Out:
# ✅ Compile completed

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np

_test_model = LogisticRegression()

X_test = np.array([
    [-2.0],
    [-1.0],
    [1.0],
    [2.0]
])

y_test = np.array([0, 0, 1, 1])

_test_model.fit(X_test, y_test)

print("✅ LogisticRegression works in this Colab runtime")
# Out:
# ✅ LogisticRegression works in this Colab runtime

# %%
# %cd /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code
# Out:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code

# %%
# !python src/04_train_eval.py \
    --config config/config.yaml \
    --mode main \
    --device cuda
# Out:
# device: cuda
#
# === GraphOmics-HCC ===
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/model.py:51: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:760.)
#   return torch.sparse_coo_tensor(idx, torch.tensor(vals), (n_nodes, n_nodes)).coalesce()
# development cohort TCGA-LIHC: 401 samples (351 tumour)
#   outer fold 1/5
#     inner early-stop AUROC 0.9933 | untouched outer AUROC 1.0000 | Platt slope 0.051
#   outer fold 2/5
#     inner early-stop AUROC 1.0000 | untouched outer AUROC 1.0000 | Platt slope 1.464
#   outer fold 3/5
#     inner early-stop AUROC 1.0000 | untouched outer AUROC 0.9900 | Platt slope 0.113
# ...

# %%
from pathlib import Path

p = Path("src/04_train_eval.py")
text = p.read_text()

# 1. Create storage for untouched outer-fold AUROCs
old = '''    fold_models = []
    fold_calibrators = []

    oof_pred = []
'''

new = '''    fold_models = []
    fold_calibrators = []
    outer_fold_aurocs = []

    oof_pred = []
'''

if old in text:
    text = text.replace(old, new, 1)

# 2. Save each untouched outer-fold AUROC
old = '''        outer_auc = roc_auc_score(
            y[va_i],
            p_va
        )

        oof_pred.append(p_va)
'''

new = '''        outer_auc = roc_auc_score(
            y[va_i],
            p_va
        )

        outer_fold_aurocs.append(
            float(outer_auc)
        )

        oof_pred.append(p_va)
'''

if old in text:
    text = text.replace(old, new, 1)

# 3. Add proper CV summary to results
old = '''        "external": {},

        "predictions": [],
'''

new = '''        "outer_fold_aurocs":
            outer_fold_aurocs,

        "internal_cv_mean_auroc":
            float(np.mean(outer_fold_aurocs)),

        "internal_cv_sd_auroc":
            float(np.std(
                outer_fold_aurocs,
                ddof=1
            )),

        "external": {},

        "predictions": [],
'''

if old in text:
    text = text.replace(old, new, 1)

# 4. Use mean untouched outer-fold AUROC for internal-external gap
text = text.replace(
    '''results["internal"]["auroc"]
            - np.mean(ext)''',
    '''results["internal_cv_mean_auroc"]
            - np.mean(ext)'''
)

# 5. Ablations should use the same internal discrimination metric
text = text.replace(
    '''"internal_auroc": r["internal"]["auroc"],''',
    '''"internal_auroc": r.get(
                    "internal_cv_mean_auroc",
                    r["internal"]["auroc"]
                ),'''
)

# 6. Remove meaningless "-hierarchy" ablation because primary hierarchy=False
text = text.replace(
    '''        "-hierarchy": {"model.use_hierarchy": False},
''',
    ""
)

p.write_text(text)

print("✅ CV reporting patch applied")
# Out:
# ✅ CV reporting patch applied

# %%
# !python -m py_compile src/04_train_eval.py
# !python -m pytest tests/ -q
# Out:
# ........................                                                 [100%]
# =============================== warnings summary ===============================
# tests/test_corrected_controls.py::test_gnnexplainer_masked_adjacency_is_differentiable
#   /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/05_explain.py:65: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:760.)
#     return torch.sparse_coo_tensor(torch.stack([src, dst]), vals,
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 24 passed, 1 warning in 6.47s

# %%
# !python src/04_train_eval.py \
    --config config/config.yaml \
    --mode baselines \
    --device cuda
# Out:
# device: cuda
#
# === GraphOmics-HCC ===
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/model.py:51: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:760.)
#   return torch.sparse_coo_tensor(idx, torch.tensor(vals), (n_nodes, n_nodes)).coalesce()
# development cohort TCGA-LIHC: 401 samples (351 tumour)
#   outer fold 1/5
#     inner early-stop AUROC 0.9933 | untouched outer AUROC 1.0000 | Platt slope 0.051
#   outer fold 2/5
#     inner early-stop AUROC 1.0000 | untouched outer AUROC 1.0000 | Platt slope 1.464
#   outer fold 3/5
#     inner early-stop AUROC 1.0000 | untouched outer AUROC 0.9900 | Platt slope 0.113
# ...

# %%
import json

with open("results/metrics_raw.json") as f:
    r = json.load(f)

g = r["graphomics"]

print("=" * 75)
print("GRAPHOMICS-HCC")
print("=" * 75)

print(
    "Outer-fold AUROCs:",
    g.get("outer_fold_aurocs")
)

print(
    "Internal CV mean AUROC:",
    g.get("internal_cv_mean_auroc")
)

print(
    "Internal CV SD:",
    g.get("internal_cv_sd_auroc")
)

print(
    "External mean AUROC:",
    g.get("external_mean_auroc")
)

print("\nBASELINES")
print("=" * 75)

for name, b in r["baselines"].items():

    print(
        name,
        "| internal =",
        round(b["internal"]["auroc"], 4),
        "| external mean =",
        round(
            b.get(
                "external_mean_auroc",
                float("nan")
            ),
            4
        )
    )
# Out:
# ...
# GRAPHOMICS-HCC
# ...
# Outer-fold AUROCs: [1.0, 1.0, 0.9900000000000001, 0.9971428571428572, 0.9885714285714285]
# Internal CV mean AUROC: 0.9951428571428572
# Internal CV SD: 0.005495824017620375
# External mean AUROC: 0.9821699778555969
#
# BASELINES
# ...
# L1 logistic | internal = 0.9962 | external mean = 0.9674
# Elastic net | internal = 0.9964 | external mean = 0.9824
# Random forest | internal = 0.9974 | external mean = 0.9824
# SVM (RBF) | internal = 0.997 | external mean = 0.9781
# MLP | internal = 0.9984 | external mean = 0.9818
# XGBoost | internal = 0.9971 | external mean = 0.977

# %%
from pathlib import Path
import shutil

src = Path("results/metrics_raw.json")
dst = Path("results/metrics_main_and_baselines.json")

shutil.copy2(src, dst)

print("✅ Saved:", dst)
# Out:
# ✅ Saved: results/metrics_main_and_baselines.json

# %%
# !grep -n -A25 "def run_ablations" src/04_train_eval.py
# Out:
# 769:def run_ablations(cfg, device):
# 770-    """Each ablation changes exactly one thing and is otherwise identical."""
# 771-    variants = {
# 772-        "full": {},
# 773-        "-PPI (degree-preserving rewired)": {"graph": "rewired"},
# 774-        "-pathway mask (dense pooling)": {"model.use_mask": False},
# 775-        "-graph smoothness": {"train.lambda_smooth": 0.0},
# 776-        "-L1 sparsity": {"train.lambda_l1": 0.0},
# 777-        "attention instead of convolution": {"model.use_attention": True},
# 778-        "depth 1": {"model.n_layers": 1},
# 779-        "depth 3": {"model.n_layers": 3},
# 780-        "-coverage mask feature": {"features": "expression_only"},
# 781-    }
# 782-    results = {}
# 783-    for name, overrides in variants.items():
# 784-        print(f"\nablation: {name}")
# 785-        c = yaml.safe_load(yaml.safe_dump(cfg))  # deep copy
# 786-        for key, val in overrides.items():
# 787-            if "." in key:
# ...

# %%
from pathlib import Path

p = Path("src/04_train_eval.py")
text = p.read_text()

text = text.replace(
    '''        "full": {},
''',
    ""
)

text = text.replace(
    '''        "-hierarchy": {"model.use_hierarchy": False},
''',
    ""
)

p.write_text(text)

print("✅ Redundant full/hierarchy variants removed")
# Out:
# ✅ Redundant full/hierarchy variants removed

# %%
# !grep -n -A20 "variants =" src/04_train_eval.py
# Out:
# 771:    variants = {
# 772-        "-PPI (degree-preserving rewired)": {"graph": "rewired"},
# 773-        "-pathway mask (dense pooling)": {"model.use_mask": False},
# 774-        "-graph smoothness": {"train.lambda_smooth": 0.0},
# 775-        "-L1 sparsity": {"train.lambda_l1": 0.0},
# 776-        "attention instead of convolution": {"model.use_attention": True},
# 777-        "depth 1": {"model.n_layers": 1},
# 778-        "depth 3": {"model.n_layers": 3},
# 779-        "-coverage mask feature": {"features": "expression_only"},
# 780-    }
# 781-    results = {}
# 782-    for name, overrides in variants.items():
# 783-        print(f"\nablation: {name}")
# 784-        c = yaml.safe_load(yaml.safe_dump(cfg))  # deep copy
# 785-        for key, val in overrides.items():
# 786-            if "." in key:
# 787-                a, b = key.split("."); c[a][b] = val
# 788-            else:
# 789-                c[key] = val
# 790-        if overrides.get("graph") == "rewired":
# ...

# %%
# !python -m py_compile src/04_train_eval.py

# %%
# !python src/04_train_eval.py \
    --config config/config.yaml \
    --mode ablations \
    --device cuda
# Out:
# device: cuda
#
# === ablations ===
#
# ablation: -PPI (degree-preserving rewired)
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/model.py:51: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:760.)
#   return torch.sparse_coo_tensor(idx, torch.tensor(vals), (n_nodes, n_nodes)).coalesce()
# development cohort TCGA-LIHC: 401 samples (351 tumour)
#   outer fold 1/5
#     inner early-stop AUROC 0.9955 | untouched outer AUROC 1.0000 | Platt slope 0.040
#   outer fold 2/5
#     inner early-stop AUROC 1.0000 | untouched outer AUROC 1.0000 | Platt slope 0.473
#   outer fold 3/5
# ...

# %%
import shutil

shutil.copy2(
    "results/metrics_raw.json",
    "results/metrics_ablations.json"
)

print("✅ Ablations preserved")
# Out:
# ✅ Ablations preserved

# %%
shutil.copy2(
    "results/metrics_main_and_baselines.json",
    "results/metrics_raw.json"
)

print("✅ Main + baseline metrics restored")
# Out:
# ✅ Main + baseline metrics restored

# %%
import json

with open("results/metrics_ablations.json") as f:
    r = json.load(f)

print("=" * 85)
print("COMPLETE ABLATION AUDIT")
print("=" * 85)

for name, m in r["ablations"].items():

    print(f"\n{name}")

    if "error" in m:
        print("  ❌ FAILED")
        print("  Error:", m["error"])

    else:
        print(
            "  ✅ Internal AUROC:",
            round(m["internal_auroc"], 4)
        )

        print(
            "  External mean AUROC:",
            round(m["external_mean_auroc"], 4)
            if m.get("external_mean_auroc") is not None
            else "NA"
        )

        print(
            "  Gap:",
            round(m["internal_external_gap"], 4)
            if m.get("internal_external_gap") is not None
            else "NA"
        )
# Out:
# ...
# COMPLETE ABLATION AUDIT
# ...
#
# -PPI (degree-preserving rewired)
#   ✅ Internal AUROC: 0.9963
#   External mean AUROC: 0.984
#   Gap: 0.0123
#
# -pathway mask (dense pooling)
#   ✅ Internal AUROC: 0.9983
#   External mean AUROC: 0.983
#   Gap: 0.0153
#
# -graph smoothness
#   ✅ Internal AUROC: 0.9966
#   External mean AUROC: 0.9821
#   Gap: 0.0144
#
# -L1 sparsity
#   ✅ Internal AUROC: 0.9951
#   External mean AUROC: 0.9822
#   Gap: 0.013
#
# attention instead of convolution
#   ❌ FAILED
# ...

# %%
failed = {
    name: m["error"]
    for name, m in r["ablations"].items()
    if "error" in m
}

print("Failed ablations:", len(failed))

for name, err in failed.items():
    print("\n", name)
    print(err)
# Out:
# Failed ablations: 1
#
#  attention instead of convolution
# OutOfMemoryError: CUDA out of memory. Tried to allocate 2.49 GiB. GPU 0 has a total capacity of 14.56 GiB of which 1.80 GiB is free. Including non-PyTorch memory, this process has 12.76 GiB memory in use. Of the allocated memory 6.55 GiB is allocated by PyTorch, and 6.08 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)

# %%
from pathlib import Path

p = Path("src/04_train_eval.py")
text = p.read_text()

old = '''    bs = cfg["train"]["batch_size"]
    history = []

    for epoch in range(cfg["train"]["max_epochs"]):
        model.train()
        perm = torch.randperm(len(Xtr), device=device)
        for i in range(0, len(perm), bs):
            idx = perm[i:i + bs]
            opt.zero_grad()
            logit, cohort_logits = model(Xtr[idx], A, ei)
            loss, _ = composite_loss(
                logit, ytr_t[idx], model, A, model.gene_scores(),
                pos_weight=pos_weight,
                lambda_l1=cfg["train"]["lambda_l1"],
                lambda_smooth=cfg["train"]["lambda_smooth"],
            )
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), cfg["train"]["grad_clip"])
            opt.step()
        sched.step()
'''

new = '''    bs = cfg["train"]["batch_size"]
    accum_steps = int(cfg["train"].get("grad_accum_steps", 1))
    history = []

    for epoch in range(cfg["train"]["max_epochs"]):
        model.train()
        perm = torch.randperm(len(Xtr), device=device)

        opt.zero_grad(set_to_none=True)

        n_batches = (len(perm) + bs - 1) // bs

        for step, i in enumerate(range(0, len(perm), bs)):
            idx = perm[i:i + bs]

            logit, cohort_logits = model(Xtr[idx], A, ei)

            loss, _ = composite_loss(
                logit, ytr_t[idx], model, A, model.gene_scores(),
                pos_weight=pos_weight,
                lambda_l1=cfg["train"]["lambda_l1"],
                lambda_smooth=cfg["train"]["lambda_smooth"],
            )

            (loss / accum_steps).backward()

            do_step = (
                ((step + 1) % accum_steps == 0)
                or (step + 1 == n_batches)
            )

            if do_step:
                torch.nn.utils.clip_grad_norm_(
                    model.parameters(),
                    cfg["train"]["grad_clip"]
                )

                opt.step()
                opt.zero_grad(set_to_none=True)

        sched.step()
'''

if old in text:
    p.write_text(text.replace(old, new, 1))
    print("✅ Gradient accumulation added")
elif 'accum_steps = int(cfg["train"].get("grad_accum_steps", 1))' in text:
    print("✅ Gradient accumulation already present")
else:
    print("⚠️ Training block not found — stop here.")
# Out:
# ✅ Gradient accumulation added

# %%
from pathlib import Path

p = Path("src/04_train_eval.py")
text = p.read_text()

old = '''def predict(model, X, A, edge_index, device, batch=32):
    model.eval()
'''

new = '''def predict(model, X, A, edge_index, device, batch=32):
    # Edge attention is substantially more memory-intensive.
    # Only the micro-batch changes; predictions are otherwise identical.
    if getattr(model, "use_attention", False):
        batch = min(batch, 4)

    model.eval()
'''

if old in text:
    p.write_text(text.replace(old, new, 1))
    print("✅ Memory-safe attention inference enabled")
elif 'if getattr(model, "use_attention", False):' in text:
    print("✅ Attention inference patch already present")
else:
    print("⚠️ predict() block not found")
# Out:
# ✅ Memory-safe attention inference enabled

# %%
# !python -m py_compile src/04_train_eval.py

# %%
# !python -m pytest tests/ -q
# Out:
# ........................                                                 [100%]
# =============================== warnings summary ===============================
# tests/test_corrected_controls.py::test_gnnexplainer_masked_adjacency_is_differentiable
#   /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/05_explain.py:65: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:760.)
#     return torch.sparse_coo_tensor(torch.stack([src, dst]), vals,
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 24 passed, 1 warning in 6.60s

# %%
from pathlib import Path

runner = r'''
import os
import sys
import json
import yaml
import torch
import importlib.util
import numpy as np

CODE = "/content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code"

os.chdir(CODE)
sys.path.insert(0, CODE + "/src")

spec = importlib.util.spec_from_file_location(
    "train_eval",
    CODE + "/src/04_train_eval.py"
)

m = importlib.util.module_from_spec(spec)
spec.loader.exec_module(m)

with open("config/config.yaml") as f:
    cfg = yaml.safe_load(f)

# Attention is the ONLY architectural change.
cfg["model"]["use_attention"] = True

# Memory-safe micro-batching:
# 4 samples × accumulation 8 = effective batch 32.
cfg["train"]["batch_size"] = 4
cfg["train"]["grad_accum_steps"] = 8

device = torch.device("cuda")

print("==============================================")
print("ATTENTION-ONLY ABLATION")
print("==============================================")
print("GPU:", torch.cuda.get_device_name(0))
print("Micro-batch:", cfg["train"]["batch_size"])
print("Accumulation:", cfg["train"]["grad_accum_steps"])
print(
    "Effective batch:",
    cfg["train"]["batch_size"]
    * cfg["train"]["grad_accum_steps"]
)

r, _ = m.run_main(
    cfg,
    device,
    save_artifacts=False
)

summary = {
    "internal_auroc": r.get(
        "internal_cv_mean_auroc",
        r["internal"]["auroc"]
    ),
    "internal_cv_sd_auroc": r.get(
        "internal_cv_sd_auroc"
    ),
    "external_mean_auroc": r.get(
        "external_mean_auroc"
    ),
    "internal_external_gap": r.get(
        "internal_external_gap"
    ),
    "outer_fold_aurocs": r.get(
        "outer_fold_aurocs"
    )
}

with open(
    "results/attention_ablation.json",
    "w"
) as f:
    json.dump(
        summary,
        f,
        indent=2
    )

print("\nATTENTION RESULT")
print(json.dumps(summary, indent=2))
'''

Path("/tmp/run_attention_ablation.py").write_text(runner)

print("✅ Attention-only runner created")
# Out:
# ✅ Attention-only runner created

# %%
# !PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True \
python /tmp/run_attention_ablation.py
# Out:
# ...
# ATTENTION-ONLY ABLATION
# ...
# GPU: Tesla T4
# Micro-batch: 4
# Accumulation: 8
# Effective batch: 32
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/model.py:51: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:760.)
#   return torch.sparse_coo_tensor(idx, torch.tensor(vals), (n_nodes, n_nodes)).coalesce()
# development cohort TCGA-LIHC: 401 samples (351 tumour)
#   outer fold 1/5
#     inner early-stop AUROC 0.9978 | untouched outer AUROC 1.0000 | Platt slope 0.058
#   outer fold 2/5
#     inner early-stop AUROC 1.0000 | untouched outer AUROC 0.9986 | Platt slope 0.140
#   outer fold 3/5
# ...

# %%
import json

with open("results/metrics_ablations.json") as f:
    all_ab = json.load(f)

with open("results/attention_ablation.json") as f:
    attention = json.load(f)

all_ab["ablations"][
    "attention instead of convolution"
] = attention

with open(
    "results/metrics_ablations_COMPLETE.json",
    "w"
) as f:
    json.dump(
        all_ab,
        f,
        indent=2
    )

print("✅ Complete ablation file created")
# Out:
# ✅ Complete ablation file created

# %%
import json

with open(
    "results/metrics_ablations_COMPLETE.json"
) as f:
    r = json.load(f)

print("=" * 88)
print("FINAL COMPLETE ABLATION RESULTS")
print("=" * 88)

for name, m in r["ablations"].items():

    if "error" in m:
        print(
            name,
            "| ❌",
            m["error"]
        )
        continue

    print(
        name,
        "| Internal =",
        round(m["internal_auroc"], 4),
        "| External =",
        round(m["external_mean_auroc"], 4),
        "| Gap =",
        round(m["internal_external_gap"], 4)
    )
# Out:
# ...
# FINAL COMPLETE ABLATION RESULTS
# ...
# -PPI (degree-preserving rewired) | Internal = 0.9963 | External = 0.984 | Gap = 0.0123
# -pathway mask (dense pooling) | Internal = 0.9983 | External = 0.983 | Gap = 0.0153
# -graph smoothness | Internal = 0.9966 | External = 0.9821 | Gap = 0.0144
# -L1 sparsity | Internal = 0.9951 | External = 0.9822 | Gap = 0.013
# attention instead of convolution | Internal = 0.9949 | External = 0.975 | Gap = 0.0199
# depth 1 | Internal = 0.9969 | External = 0.9806 | Gap = 0.0163
# depth 3 | Internal = 0.9954 | External = 0.9819 | Gap = 0.0135
# -coverage mask feature | Internal = 0.9957 | External = 0.9804 | Gap = 0.0153

# %%
from pathlib import Path
import shutil

backup = Path("results/final_core_results")
backup.mkdir(exist_ok=True)

for f in [
    "metrics_main_and_baselines.json",
    "metrics_ablations_COMPLETE.json",
    "metrics_raw.json",
    "model_weights.pt",
    "fold_calibration.json",
    "predictions_graphomics.csv",
    "training_history.json",
    "graph_stats.json",
]:
    src = Path("results") / f
    if src.exists():
        shutil.copy2(src, backup / f)

print("✅ Core results backed up")
# Out:
# ✅ Core results backed up

# %%
from pathlib import Path

required = [
    "results/model_weights.pt",
    "data/processed/expression.parquet",
    "data/processed/sample_table.csv",
    "data/processed/coverage.parquet",
    "data/processed/edge_index.npy",
    "data/processed/edge_weight.npy",
    "data/processed/pathway_mask.npz",
    "data/processed/pathway_names.json",
]

for f in required:
    p = Path(f)
    print("✅" if p.exists() else "❌", f)
# Out:
# ✅ results/model_weights.pt
# ✅ data/processed/expression.parquet
# ✅ data/processed/sample_table.csv
# ✅ data/processed/coverage.parquet
# ✅ data/processed/edge_index.npy
# ✅ data/processed/edge_weight.npy
# ✅ data/processed/pathway_mask.npz
# ✅ data/processed/pathway_names.json

# %%
# %cd /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code

# !PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True \
python src/05_explain.py \
    --config config/config.yaml \
    --device cuda
# Out:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/src/model.py:51: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:760.)
#   return torch.sparse_coo_tensor(idx, torch.tensor(vals), (n_nodes, n_nodes)).coalesce()
# loaded 5 fold-models
#
# Integrated Gradients
#     fold-model 0: mean completeness error 1.1576e-06
#     fold-model 1: mean completeness error 6.6982e-02
#     fold-model 2: mean completeness error 6.0601e-06
#     fold-model 3: mean completeness error 6.8517e-06
#     fold-model 4: mean completeness error 1.0195e-01
# ...

# %%
import json
import pandas as pd
from pathlib import Path

print("=" * 80)
print("GRAPHOMICS-HCC EXPLAINABILITY SUMMARY")
print("=" * 80)

with open("results/explanation_stability.json") as f:
    ex = json.load(f)

print("\nSTABILITY")
print(json.dumps(ex["stability"], indent=2))

print("\nSANITY CHECKS")
print(json.dumps(ex["sanity_checks"], indent=2))

print("\nSUBNETWORK")
print(json.dumps(ex["subnetwork"], indent=2))

print("\nSignificant pathways:",
      ex["n_significant_pathways"])

print("Enriched terms:",
      ex["n_enriched_terms"])

print("\nTop genes:")
print(ex["top_genes"])

genes = pd.read_csv(
    "results/gene_attributions_full.csv"
)

print("\nTOP 20 GENES")
display(
    genes[
        [
            "gene",
            "mean_attribution",
            "abs_attribution",
            "sd_across_folds",
            "sign_consistency"
        ]
    ].head(20)
)

pw = pd.read_csv(
    "results/pathway_differential.csv"
)

print("\nTOP 20 DIFFERENTIAL PATHWAYS")
display(
    pw.head(20)
)

if Path("results/pathway_shap.csv").exists():
    shap = pd.read_csv(
        "results/pathway_shap.csv"
    )

    print("\nTOP 20 SHAP PATHWAYS")
    display(shap.head(20))
else:
    print("\n⚠️ pathway_shap.csv was not produced")
# Out:
# ...
# GRAPHOMICS-HCC EXPLAINABILITY SUMMARY
# ...
#
# STABILITY
# {
#   "top_10": {
#     "mean_jaccard": 0.03742690058479532,
#     "sd_jaccard": 0.036800310462110575,
#     "n_pairs": 10
#   },
#   "top_25": {
#     "mean_jaccard": 0.06444530934671047,
#     "sd_jaccard": 0.06100110404891681,
#     "n_pairs": 10
#   },
#   "top_50": {
#     "mean_jaccard": 0.09166854131123423,
#     "sd_jaccard": 0.052988888654586064,
#     "n_pairs": 10
#   },
#   "top_100": {
#     "mean_jaccard": 0.11510494922288061,
#     "sd_jaccard": 0.05780421917579804,
#     "n_pairs": 10
#   },
#   "mean_spearman_between_models": 0.13511871794075495,
#   "ig_completeness_error_mean": 0.03378891723783839
# }
#
# SANITY CHECKS
# {
#   "label_randomisation_spearman": -0.08338083802911739,
#   "parameter_randomisation_spearman": -0.0005294381875633302,
# ...

# %%
import pandas as pd
from pathlib import Path

p = Path("results/predictions_graphomics.csv")

print("Predictions exist:", p.exists())

pred = pd.read_csv(p)

print("Columns:", pred.columns.tolist())
print("\nSamples by cohort:")
print(pred.groupby("cohort").size())

print("\nTCGA tumour predictions:")
tcga_tum = pred[
    (pred["cohort"] == "TCGA-LIHC") &
    (pred["y"] == 1)
]

print(tcga_tum.shape)
print(tcga_tum[["sample", "p", "y"]].head())
# Out:
# Predictions exist: True
# Columns: ['sample', 'cohort', 'model', 'p', 'y', 'split']
#
# Samples by cohort:
# cohort
# GSE14520     418
# GSE25097     493
# GSE36376     418
# GSE64041     111
# GSE76427     161
# TCGA-LIHC    401
# dtype: int64
#
# TCGA tumour predictions:
# (351, 6)
#              sample         p  y
# 0  TCGA-DD-A3A8-01A  0.875003  1
# 1  TCGA-CC-A7IE-01A  0.875018  1
# 2  TCGA-ED-A7XO-01A  0.874993  1
# 3  TCGA-ED-A8O6-01A  0.875018  1
# 4  TCGA-XR-A8TG-01A  0.875001  1

# %%
import pandas as pd

clin = pd.read_csv(
    "data/raw/tcga/tcga_lihc_clinical.csv"
)

print("Clinical shape:", clin.shape)

required = [
    "submitter_id",
    "demographic.vital_status",
    "demographic.days_to_death",
    "diagnoses.days_to_last_follow_up",
    "diagnoses.age_at_diagnosis",
    "demographic.gender",
    "diagnoses.ajcc_pathologic_stage",
]

for c in required:
    print(
        "✅" if c in clin.columns else "❌",
        c
    )
# Out:
# Clinical shape: (377, 8)
# ✅ submitter_id
# ✅ demographic.vital_status
# ✅ demographic.days_to_death
# ✅ diagnoses.days_to_last_follow_up
# ✅ diagnoses.age_at_diagnosis
# ✅ demographic.gender
# ✅ diagnoses.ajcc_pathologic_stage

# %%
# !python src/06_survival.py \
    --config config/config.yaml
# Out:
# pre-specified cut-point (development median): 0.8770
#
# TCGA-LIHC
#   316 tumours with survival annotation
# The ``p_value_threshold`` is set at 0.05. Even under the null hypothesis of no violations, some
# covariates will be below the threshold by chance. This is compounded when there are many covariates.
# Similarly, when there are lots of observations, even minor deviances from the proportional hazard
# assumption will be flagged.
#
# With that in mind, it's best to use a combination of statistical tests and visual tests to determine
# the most serious violations. Produce visual plots using ``check_assumptions(..., show_plots=True)``
# and looking for non-constant lines. See link [A] below for a full example.
#
# <IPython.core.display.HTML object>
#
#
# 1. Variable 'score' failed the non-proportional test: p-value is 0.0195.
#
#    Advice 1: the functional form of the variable 'score' might be incorrect. That is, there may be
# ...

# %%
import json

with open("results/survival.json") as f:
    s = json.load(f)

print("=" * 75)
print("GRAPHOMICS-HCC EXPLORATORY SURVIVAL ANALYSIS")
print("=" * 75)

print("\nPre-specified cutpoint:")
print(s["cutpoint"])

for cohort, r in s["cohorts"].items():

    print("\n" + "=" * 60)
    print(cohort)
    print("=" * 60)

    if "skipped" in r:
        print("SKIPPED:", r["skipped"])
        continue

    for key, value in r.items():
        print(f"{key}: {value}")
# Out:
# ...
# GRAPHOMICS-HCC EXPLORATORY SURVIVAL ANALYSIS
# ...
#
# Pre-specified cutpoint:
# 0.8769748169896981
#
# ...
# TCGA-LIHC
# ...
# cohort: TCGA-LIHC
# n: 316
# n_events: 122
# n_high: 157
# n_low: 159
# cutpoint: 0.8769748169896981
# cutpoint_source: median score of the development cohort (pre-specified)
# logrank_p: 0.017298653903821286
# median_os_high: 37.746386333771355
# median_os_low: 55.35479632063075
# hr_univariable: 5.430670404683172
# hr_univariable_ci: [0.675725673189124, 43.64519836150628]
# c_index: 0.5939719541067201
# hr_adjusted: 3.2610607940959633
# hr_adjusted_ci: [0.40453771965241864, 26.288073982141984]
# hr_adjusted_p: 0.2669699861053175
# c_index_adjusted: 0.6422976501305483
# adjusted_for: ['age', 'stage']
# c_index_clinical_only: 0.6269944879605454
# delta_c_index: 0.015303162170002937
# ph_assumption_violations: 0
# time_dependent_auc: scikit-survival not installed — omit this row from Table S16

# %%
from pathlib import Path
import shutil
import json

final_dir = Path("results/FINAL_GRAPHOMICS_HCC")
final_dir.mkdir(parents=True, exist_ok=True)

files_to_save = [
    "metrics_main_and_baselines.json",
    "metrics_ablations_COMPLETE.json",
    "metrics_raw.json",
    "graph_stats.json",
    "survival.json",
    "survival_curves.csv",
    "gene_attributions_full.csv",
    "pathway_differential.csv",
    "pathway_shap.csv",
    "explanation_stability.json",
    "predictions_graphomics.csv",
    "fold_calibration.json",
    "training_history.json",
    "model_weights.pt",
]

for name in files_to_save:
    src = Path("results") / name
    if src.exists():
        shutil.copy2(src, final_dir / name)
        print("✅", name)
    else:
        print("⚠️ missing:", name)

print("\nFinal results folder:")
print(final_dir.resolve())
# Out:
# ✅ metrics_main_and_baselines.json
# ✅ metrics_ablations_COMPLETE.json
# ✅ metrics_raw.json
# ✅ graph_stats.json
# ✅ survival.json
# ✅ survival_curves.csv
# ✅ gene_attributions_full.csv
# ✅ pathway_differential.csv
# ✅ pathway_shap.csv
# ✅ explanation_stability.json
# ✅ predictions_graphomics.csv
# ✅ fold_calibration.json
# ✅ training_history.json
# ✅ model_weights.pt
#
# Final results folder:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code/results/FINAL_GRAPHOMICS_HCC

# %%
# %%writefile src/07_make_publication_figures.py

from pathlib import Path
import json
import textwrap
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import FancyBboxPatch
from matplotlib.ticker import FormatStrFormatter

from sklearn.metrics import (
    roc_curve,
    roc_auc_score,
    precision_recall_curve,
    average_precision_score,
)

warnings.filterwarnings("ignore")

# ============================================================
# PATHS
# ============================================================

ROOT = Path(".")
RESULTS = ROOT / "results"
PROCESSED = ROOT / "data" / "processed"

OUT = RESULTS / "publication_outputs"
FIGDIR = OUT / "figures"
TABLEDIR = OUT / "tables"

FIGDIR.mkdir(parents=True, exist_ok=True)
TABLEDIR.mkdir(parents=True, exist_ok=True)


# ============================================================
# STYLE
# ============================================================

BLUE = "#2457A7"
LIGHT_BLUE = "#5B8FD1"
GREEN = "#2A9D6F"
DARK_GREEN = "#147D64"
ORANGE = "#E79032"
RED = "#C94C4C"
PURPLE = "#775DA6"
GRAY = "#777777"
LIGHT_GRAY = "#E9EDF2"
DARK = "#263238"

COHORT_COLORS = {
    "TCGA-LIHC": "#2457A7",
    "GSE14520": "#2A9D6F",
    "GSE25097": "#E79032",
    "GSE36376": "#775DA6",
    "GSE76427": "#C94C4C",
    "GSE64041": "#5B8FD1",
}

plt.rcParams.update({
    "font.family": "DejaVu Sans",
    "font.size": 10,
    "axes.titlesize": 13,
    "axes.labelsize": 11,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "legend.fontsize": 9,
    "axes.linewidth": 0.8,
    "figure.facecolor": "white",
    "axes.facecolor": "white",
    "savefig.facecolor": "white",
    "pdf.fonttype": 42,
    "ps.fonttype": 42,
})


def save_figure(fig, name):
    png = FIGDIR / f"{name}.png"
    pdf = FIGDIR / f"{name}.pdf"

    fig.savefig(
        png,
        dpi=600,
        bbox_inches="tight",
        facecolor="white"
    )

    fig.savefig(
        pdf,
        bbox_inches="tight",
        facecolor="white"
    )

    plt.close(fig)

    print("✅", png)
    print("✅", pdf)


def clean_axes(ax):
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.grid(
        axis="y",
        alpha=0.15,
        linewidth=0.7
    )


def pretty_pathway(x, width=38):
    x = str(x)

    for prefix in [
        "REACTOME_",
        "KEGG_MEDICUS_REFERENCE_",
        "KEGG_MEDICUS_",
        "KEGG_"
    ]:
        if x.startswith(prefix):
            x = x[len(prefix):]

    x = x.replace("_", " ").title()

    return "\n".join(
        textwrap.wrap(
            x,
            width=width
        )
    )


# ============================================================
# LOAD RESULTS
# ============================================================

main_file = RESULTS / "metrics_main_and_baselines.json"

if not main_file.exists():
    main_file = RESULTS / "metrics_raw.json"

with open(main_file) as f:
    MAIN = json.load(f)

G = MAIN["graphomics"]

baseline_results = MAIN.get(
    "baselines",
    {}
)

ablation_file = (
    RESULTS /
    "metrics_ablations_COMPLETE.json"
)

ABLATIONS = {}

if ablation_file.exists():
    with open(ablation_file) as f:
        ABLATIONS = json.load(f).get(
            "ablations",
            {}
        )

graph_file = RESULTS / "graph_stats.json"

GRAPH = {}

if graph_file.exists():
    with open(graph_file) as f:
        GRAPH = json.load(f)

survival_file = RESULTS / "survival.json"

SURVIVAL = {}

if survival_file.exists():
    with open(survival_file) as f:
        SURVIVAL = json.load(f)

samples = pd.read_csv(
    PROCESSED /
    "sample_table.csv"
)

pred = pd.read_csv(
    RESULTS /
    "predictions_graphomics.csv"
)


# ============================================================
# TABLE 1 — COHORT COMPOSITION
# ============================================================

cohort_table = (
    samples
    .groupby(
        ["cohort", "tumour"]
    )
    .size()
    .unstack(fill_value=0)
)

cohort_table = cohort_table.rename(
    columns={
        0: "Non-tumour",
        1: "Tumour"
    }
)

for col in [
    "Non-tumour",
    "Tumour"
]:
    if col not in cohort_table.columns:
        cohort_table[col] = 0

cohort_table["Total"] = (
    cohort_table["Non-tumour"]
    + cohort_table["Tumour"]
)

cohort_table = (
    cohort_table[
        [
            "Non-tumour",
            "Tumour",
            "Total"
        ]
    ]
    .reset_index()
)

preferred_order = [
    "TCGA-LIHC",
    "GSE14520",
    "GSE25097",
    "GSE36376",
    "GSE76427",
    "GSE64041"
]

cohort_table["order"] = (
    cohort_table["cohort"]
    .map(
        {
            c: i
            for i, c
            in enumerate(preferred_order)
        }
    )
)

cohort_table = (
    cohort_table
    .sort_values("order")
    .drop(columns="order")
)

cohort_table.to_csv(
    TABLEDIR /
    "Table1_Cohort_Composition.csv",
    index=False
)


# ============================================================
# FIGURE 1 — STUDY WORKFLOW
# ============================================================

fig, ax = plt.subplots(
    figsize=(15, 4.8)
)

ax.set_xlim(0, 15)
ax.set_ylim(0, 5)
ax.axis("off")

boxes = [
    (
        0.35, 1.55, 2.0, 1.8,
        "Multi-cohort\ntranscriptomics",
        "TCGA-LIHC +\n5 GEO cohorts",
        BLUE
    ),
    (
        2.75, 1.55, 2.0, 1.8,
        "Preprocessing",
        "QC • gene mapping\nrank normalization",
        LIGHT_BLUE
    ),
    (
        5.15, 1.55, 2.0, 1.8,
        "Biological graph",
        "STRING v12.0\nscore ≥700",
        GREEN
    ),
    (
        7.55, 1.55, 2.0, 1.8,
        "Pathway layer",
        "MSigDB C2:CP\n1,852 pathways",
        DARK_GREEN
    ),
    (
        9.95, 1.55, 2.0, 1.8,
        "GraphOmics-HCC",
        "2-layer GNN\nbiological pooling",
        PURPLE
    ),
    (
        12.35, 1.55, 2.0, 1.8,
        "Validation",
        "5-fold TCGA CV\n5 external cohorts",
        ORANGE
    ),
]

for x, y, w, h, title, subtitle, color in boxes:

    shadow = FancyBboxPatch(
        (x + 0.06, y - 0.06),
        w,
        h,
        boxstyle="round,pad=0.04,rounding_size=0.12",
        facecolor="#D9DEE5",
        edgecolor="none",
        alpha=0.55
    )

    ax.add_patch(shadow)

    box = FancyBboxPatch(
        (x, y),
        w,
        h,
        boxstyle="round,pad=0.04,rounding_size=0.12",
        facecolor="white",
        edgecolor=color,
        linewidth=2.0
    )

    ax.add_patch(box)

    ax.add_patch(
        FancyBboxPatch(
            (x, y + h - 0.43),
            w,
            0.43,
            boxstyle="round,pad=0.04,rounding_size=0.12",
            facecolor=color,
            edgecolor=color
        )
    )

    ax.text(
        x + w / 2,
        y + h - 0.22,
        title,
        ha="center",
        va="center",
        fontsize=10.5,
        fontweight="bold",
        color="white"
    )

    ax.text(
        x + w / 2,
        y + 0.60,
        subtitle,
        ha="center",
        va="center",
        fontsize=9.2,
        color=DARK,
        linespacing=1.35
    )

for i in range(len(boxes) - 1):

    x1 = boxes[i][0] + boxes[i][2]
    x2 = boxes[i + 1][0]

    ax.annotate(
        "",
        xy=(x2 - 0.08, 2.45),
        xytext=(x1 + 0.08, 2.45),
        arrowprops=dict(
            arrowstyle="-|>",
            color="#68737D",
            lw=1.8
        )
    )

ax.text(
    7.5,
    4.42,
    "GraphOmics-HCC: biologically structured multi-cohort HCC classification",
    ha="center",
    fontsize=15,
    fontweight="bold",
    color=DARK
)

ax.text(
    7.5,
    0.58,
    "Explainability • pathway analysis • ablations • exploratory survival analysis",
    ha="center",
    fontsize=10.5,
    color=GRAY
)

save_figure(
    fig,
    "Figure1_GraphOmics_HCC_Workflow"
)


# ============================================================
# FIGURE 2 — COHORT COMPOSITION
# ============================================================

plot_df = cohort_table.copy()

fig, ax = plt.subplots(
    figsize=(9.5, 5.6)
)

x = np.arange(len(plot_df))

non = plot_df["Non-tumour"].values
tum = plot_df["Tumour"].values

ax.bar(
    x,
    non,
    width=0.68,
    label="Non-tumour",
    color=LIGHT_BLUE,
    edgecolor="white",
    linewidth=0.7
)

ax.bar(
    x,
    tum,
    bottom=non,
    width=0.68,
    label="Tumour",
    color=GREEN,
    edgecolor="white",
    linewidth=0.7
)

for i, (a, b) in enumerate(
    zip(non, tum)
):
    ax.text(
        i,
        a / 2,
        str(int(a)),
        ha="center",
        va="center",
        fontsize=8.5,
        color="white",
        fontweight="bold"
    )

    ax.text(
        i,
        a + b / 2,
        str(int(b)),
        ha="center",
        va="center",
        fontsize=8.5,
        color="white",
        fontweight="bold"
    )

    ax.text(
        i,
        a + b + 8,
        f"n={int(a+b)}",
        ha="center",
        fontsize=8.5,
        color=DARK
    )

ax.set_xticks(x)

ax.set_xticklabels(
    plot_df["cohort"],
    rotation=25,
    ha="right"
)

ax.set_ylabel("Number of samples")

ax.set_title(
    "Final analytic cohort composition after quality control",
    fontweight="bold",
    pad=12
)

ax.legend(
    frameon=False,
    ncol=2,
    loc="upper right"
)

clean_axes(ax)

save_figure(
    fig,
    "Figure2_Cohort_Composition"
)


# ============================================================
# FIGURE 3 — ROC CURVES
# ============================================================

fig, ax = plt.subplots(
    figsize=(7.8, 7.0)
)

cohort_order = [
    c for c in preferred_order
    if c in pred["cohort"].unique()
]

for cohort in cohort_order:

    d = pred[
        pred["cohort"] == cohort
    ]

    if d["y"].nunique() < 2:
        continue

    fpr, tpr, _ = roc_curve(
        d["y"],
        d["p"]
    )

    auc_val = roc_auc_score(
        d["y"],
        d["p"]
    )

    label = (
        f"{cohort} "
        f"(AUC={auc_val:.3f})"
    )

    ax.plot(
        fpr,
        tpr,
        lw=2.2,
        label=label,
        color=COHORT_COLORS.get(
            cohort,
            None
        )
    )

ax.plot(
    [0, 1],
    [0, 1],
    "--",
    color="#A7ADB4",
    lw=1.2,
    label="Chance"
)

ax.set_xlim(0, 1)
ax.set_ylim(0, 1.02)

ax.set_xlabel(
    "False-positive rate"
)

ax.set_ylabel(
    "True-positive rate"
)

ax.set_title(
    "GraphOmics-HCC discrimination across development and external cohorts",
    fontweight="bold",
    pad=12
)

ax.legend(
    frameon=False,
    loc="lower right"
)

ax.grid(
    alpha=0.16
)

ax.set_aspect(
    "equal",
    adjustable="box"
)

save_figure(
    fig,
    "Figure3_ROC_Curves"
)


# ============================================================
# SUPPLEMENTARY FIGURE — PR CURVES
# ============================================================

fig, ax = plt.subplots(
    figsize=(7.8, 7.0)
)

for cohort in cohort_order:

    d = pred[
        pred["cohort"] == cohort
    ]

    if d["y"].nunique() < 2:
        continue

    precision, recall, _ = (
        precision_recall_curve(
            d["y"],
            d["p"]
        )
    )

    ap = average_precision_score(
        d["y"],
        d["p"]
    )

    ax.plot(
        recall,
        precision,
        lw=2.2,
        label=(
            f"{cohort} "
            f"(AP={ap:.3f})"
        ),
        color=COHORT_COLORS.get(
            cohort,
            None
        )
    )

ax.set_xlim(0, 1)
ax.set_ylim(0, 1.02)

ax.set_xlabel("Recall")
ax.set_ylabel("Precision")

ax.set_title(
    "Precision–recall performance across cohorts",
    fontweight="bold",
    pad=12
)

ax.legend(
    frameon=False,
    loc="lower left"
)

ax.grid(alpha=0.16)

save_figure(
    fig,
    "FigureS1_Precision_Recall_Curves"
)


# ============================================================
# TABLE 2 — GRAPHOMICS PERFORMANCE
# ============================================================

performance_rows = []

internal = G.get(
    "internal",
    {}
)

tcga_n = int(
    cohort_table.loc[
        cohort_table["cohort"]
        == "TCGA-LIHC",
        "Total"
    ].iloc[0]
)

tcga_pos = int(
    cohort_table.loc[
        cohort_table["cohort"]
        == "TCGA-LIHC",
        "Tumour"
    ].iloc[0]
)

performance_rows.append({
    "Cohort": "TCGA-LIHC",
    "Role": "Development / outer CV",
    "n": tcga_n,
    "Tumour": tcga_pos,
    "AUROC": G.get(
        "internal_cv_mean_auroc",
        internal.get("auroc")
    ),
    "AUROC_CI_low": np.nan,
    "AUROC_CI_high": np.nan,
    "CV_SD": G.get(
        "internal_cv_sd_auroc",
        np.nan
    ),
    "AUPRC": internal.get(
        "auprc",
        np.nan
    ),
    "Sensitivity": internal.get(
        "sensitivity",
        np.nan
    ),
    "Specificity": internal.get(
        "specificity",
        np.nan
    ),
    "Balanced_accuracy": internal.get(
        "balanced_accuracy",
        np.nan
    ),
    "F1": internal.get(
        "f1",
        np.nan
    ),
    "MCC": internal.get(
        "mcc",
        np.nan
    ),
    "Brier": internal.get(
        "brier",
        np.nan
    ),
})

for cohort, m in G.get(
    "external",
    {}
).items():

    performance_rows.append({
        "Cohort": cohort,
        "Role": "External validation",
        "n": m.get("n"),
        "Tumour": m.get("n_pos"),
        "AUROC": m.get("auroc"),
        "AUROC_CI_low": m.get(
            "auroc_ci_low"
        ),
        "AUROC_CI_high": m.get(
            "auroc_ci_high"
        ),
        "CV_SD": np.nan,
        "AUPRC": m.get("auprc"),
        "Sensitivity": m.get(
            "sensitivity"
        ),
        "Specificity": m.get(
            "specificity"
        ),
        "Balanced_accuracy": m.get(
            "balanced_accuracy"
        ),
        "F1": m.get("f1"),
        "MCC": m.get("mcc"),
        "Brier": m.get("brier"),
    })

performance_table = pd.DataFrame(
    performance_rows
)

performance_table.to_csv(
    TABLEDIR /
    "Table2_GraphOmics_Diagnostic_Performance.csv",
    index=False
)


# ============================================================
# FIGURE 4 — EXTERNAL AUROC FOREST
# ============================================================

external = G.get(
    "external",
    {}
)

forest_rows = []

for cohort, m in external.items():

    forest_rows.append({
        "cohort": cohort,
        "auc": m["auroc"],
        "low": m["auroc_ci_low"],
        "high": m["auroc_ci_high"],
        "n": m["n"],
    })

forest = pd.DataFrame(
    forest_rows
).sort_values(
    "auc",
    ascending=True
)

fig, ax = plt.subplots(
    figsize=(8.5, 5.2)
)

y = np.arange(
    len(forest)
)

xerr = np.vstack([
    forest["auc"] - forest["low"],
    forest["high"] - forest["auc"]
])

ax.errorbar(
    forest["auc"],
    y,
    xerr=xerr,
    fmt="o",
    markersize=8,
    color=BLUE,
    ecolor=LIGHT_BLUE,
    elinewidth=2.2,
    capsize=4
)

for i, row in forest.reset_index(
    drop=True
).iterrows():

    ax.text(
        min(
            row["high"] + 0.004,
            1.005
        ),
        i,
        f'{row["auc"]:.3f}',
        va="center",
        fontsize=9
    )

ax.set_yticks(y)

ax.set_yticklabels([
    f'{r.cohort}  (n={r.n})'
    for r in forest.itertuples()
])

ax.set_xlim(
    max(
        0.75,
        forest["low"].min() - 0.03
    ),
    1.01
)

ax.axvline(
    0.5,
    linestyle="--",
    color="#BBBBBB",
    lw=1
)

ax.set_xlabel(
    "AUROC (95% bootstrap CI)"
)

ax.set_title(
    "External validation across five independent HCC cohorts",
    fontweight="bold",
    pad=12
)

ax.grid(
    axis="x",
    alpha=0.18
)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)

save_figure(
    fig,
    "Figure4_External_AUROC_Forest"
)


# ============================================================
# TABLE 3 + FIGURE 5 — MODEL COMPARISON
# ============================================================

external_cohorts = [
    "GSE14520",
    "GSE25097",
    "GSE36376",
    "GSE76427",
    "GSE64041"
]

comparison_rows = []

row = {
    "Model": "GraphOmics-HCC",
    "Internal_AUROC":
        G.get(
            "internal_cv_mean_auroc",
            internal.get("auroc")
        ),
}

for c in external_cohorts:
    row[c] = (
        G.get("external", {})
        .get(c, {})
        .get("auroc", np.nan)
    )

row["External_mean_AUROC"] = (
    G.get(
        "external_mean_auroc",
        np.nan
    )
)

row["Internal_external_gap"] = (
    G.get(
        "internal_external_gap",
        np.nan
    )
)

comparison_rows.append(row)


for name, b in baseline_results.items():

    r = {
        "Model": name,
        "Internal_AUROC":
            b.get(
                "internal",
                {}
            ).get(
                "auroc",
                np.nan
            ),
    }

    for c in external_cohorts:
        r[c] = (
            b.get(
                "external",
                {}
            ).get(
                c,
                {}
            ).get(
                "auroc",
                np.nan
            )
        )

    r["External_mean_AUROC"] = (
        b.get(
            "external_mean_auroc",
            np.nan
        )
    )

    r["Internal_external_gap"] = (
        b.get(
            "internal_external_gap",
            np.nan
        )
    )

    comparison_rows.append(r)


comparison = pd.DataFrame(
    comparison_rows
)

comparison.to_csv(
    TABLEDIR /
    "Table3_Model_Comparison.csv",
    index=False
)


heat_cols = (
    external_cohorts
    + ["External_mean_AUROC"]
)

heat = comparison.set_index(
    "Model"
)[heat_cols]

fig, ax = plt.subplots(
    figsize=(11.5, 6.0)
)

vals = heat.values.astype(float)

vmin = max(
    0.80,
    np.nanmin(vals) - 0.02
)

im = ax.imshow(
    vals,
    aspect="auto",
    cmap="YlGnBu",
    vmin=vmin,
    vmax=1.0
)

ax.set_xticks(
    np.arange(len(heat_cols))
)

ax.set_xticklabels(
    [
        x.replace(
            "External_mean_AUROC",
            "External mean"
        )
        for x in heat_cols
    ],
    rotation=28,
    ha="right"
)

ax.set_yticks(
    np.arange(len(heat.index))
)

ax.set_yticklabels(
    heat.index
)

for i in range(vals.shape[0]):
    for j in range(vals.shape[1]):

        if np.isnan(vals[i, j]):
            txt = "NA"
        else:
            txt = f"{vals[i,j]:.3f}"

        ax.text(
            j,
            i,
            txt,
            ha="center",
            va="center",
            fontsize=8.5,
            color=(
                "white"
                if (
                    not np.isnan(vals[i,j])
                    and vals[i,j] >
                    (vmin + 1) / 2
                )
                else DARK
            ),
            fontweight=(
                "bold"
                if i == 0
                else "normal"
            )
        )

cbar = fig.colorbar(
    im,
    ax=ax,
    fraction=0.032,
    pad=0.03
)

cbar.set_label(
    "AUROC"
)

ax.set_title(
    "External validation performance of GraphOmics-HCC and conventional baselines",
    fontweight="bold",
    pad=14
)

for spine in ax.spines.values():
    spine.set_visible(False)

save_figure(
    fig,
    "Figure5_Model_Comparison_Heatmap"
)


# ============================================================
# TABLE 4 + FIGURE 6 — ABLATIONS
# ============================================================

ablation_rows = []

full_external = G.get(
    "external_mean_auroc",
    np.nan
)

full_internal = G.get(
    "internal_cv_mean_auroc",
    internal.get(
        "auroc",
        np.nan
    )
)

for name, m in ABLATIONS.items():

    if "error" in m:
        continue

    ext_auc = m.get(
        "external_mean_auroc",
        np.nan
    )

    int_auc = m.get(
        "internal_auroc",
        np.nan
    )

    ablation_rows.append({
        "Variant": name,
        "Internal_AUROC":
            int_auc,
        "External_mean_AUROC":
            ext_auc,
        "Delta_external_vs_full":
            ext_auc - full_external,
        "Internal_external_gap":
            m.get(
                "internal_external_gap",
                np.nan
            ),
    })


ablation_table = pd.DataFrame(
    ablation_rows
)

ablation_table.to_csv(
    TABLEDIR /
    "Table4_Ablation_Analysis.csv",
    index=False
)


if len(ablation_table):

    plot = (
        ablation_table
        .sort_values(
            "Delta_external_vs_full"
        )
        .copy()
    )

    fig, ax = plt.subplots(
        figsize=(9.5, 6.0)
    )

    colors = [
        GREEN if x >= 0
        else BLUE
        for x in
        plot["Delta_external_vs_full"]
    ]

    bars = ax.barh(
        plot["Variant"],
        plot[
            "Delta_external_vs_full"
        ],
        color=colors,
        alpha=0.9
    )

    ax.axvline(
        0,
        color=DARK,
        lw=1.2
    )

    for bar, val in zip(
        bars,
        plot[
            "Delta_external_vs_full"
        ]
    ):

        ax.text(
            val + (
                0.00015
                if val >= 0
                else -0.00015
            ),
            bar.get_y()
            + bar.get_height()/2,
            f"{val:+.4f}",
            ha=(
                "left"
                if val >= 0
                else "right"
            ),
            va="center",
            fontsize=8.5
        )

    ax.set_xlabel(
        "Change in mean external AUROC vs full GraphOmics-HCC"
    )

    ax.set_title(
        "Ablation analysis: effect of individual architectural components",
        fontweight="bold",
        pad=12
    )

    ax.grid(
        axis="x",
        alpha=0.15
    )

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_visible(False)

    save_figure(
        fig,
        "Figure6_Ablation_Delta_AUROC"
    )


# ============================================================
# TABLE 5 — GRAPH CHARACTERISTICS
# ============================================================

graph_labels = {
    "n_genes":
        "Gene nodes",
    "n_edges":
        "STRING edges",
    "mean_degree":
        "Mean degree",
    "median_degree":
        "Median degree",
    "max_degree":
        "Maximum degree",
    "n_isolated":
        "Isolated genes",
    "largest_component_fraction":
        "Largest component fraction",
    "n_components":
        "Connected components",
    "n_pathways":
        "MSigDB pathways",
    "pathway_density":
        "Gene-pathway mask density",
    "genes_per_pathway_mean":
        "Mean genes per pathway",
    "pathways_per_gene_mean":
        "Mean pathways per gene",
    "gene_pathway_coverage":
        "Gene pathway coverage",
    "string_cutoff":
        "STRING score threshold",
    "string_version":
        "STRING version",
    "msigdb_collection":
        "MSigDB collection",
}

graph_rows = []

for key, label in graph_labels.items():

    if key in GRAPH:
        graph_rows.append({
            "Characteristic": label,
            "Value": GRAPH[key]
        })

graph_table = pd.DataFrame(
    graph_rows
)

graph_table.to_csv(
    TABLEDIR /
    "Table5_Graph_Characteristics.csv",
    index=False
)


# ============================================================
# FIGURE 7 — EXPLAINABILITY
# ============================================================

gene_file = (
    RESULTS /
    "gene_attributions_full.csv"
)

shap_file = (
    RESULTS /
    "pathway_shap.csv"
)

if (
    gene_file.exists()
    and shap_file.exists()
):

    genes = pd.read_csv(
        gene_file
    )

    pathways = pd.read_csv(
        shap_file
    )

    top_genes = (
        genes
        .sort_values(
            "abs_attribution",
            ascending=False
        )
        .head(15)
        .sort_values(
            "abs_attribution",
            ascending=True
        )
    )

    top_pathways = (
        pathways
        .sort_values(
            "mean_abs_shap",
            ascending=False
        )
        .head(15)
        .sort_values(
            "mean_abs_shap",
            ascending=True
        )
    )

    fig, axes = plt.subplots(
        1,
        2,
        figsize=(15, 8)
    )

    # --------------------------------------------------------
    # Gene attribution
    # --------------------------------------------------------

    gene_colors = [
        GREEN
        if x >= 0
        else BLUE
        for x in
        top_genes[
            "mean_attribution"
        ]
    ]

    axes[0].barh(
        top_genes["gene"],
        top_genes[
            "mean_attribution"
        ],
        color=gene_colors,
        alpha=0.92
    )

    axes[0].axvline(
        0,
        color=DARK,
        lw=1
    )

    axes[0].set_xlabel(
        "Mean integrated-gradient attribution"
    )

    axes[0].set_title(
        "A  Top gene-level attributions",
        loc="left",
        fontweight="bold"
    )

    axes[0].grid(
        axis="x",
        alpha=0.15
    )

    axes[0].spines[
        "top"
    ].set_visible(False)

    axes[0].spines[
        "right"
    ].set_visible(False)


    # --------------------------------------------------------
    # Pathway SHAP
    # --------------------------------------------------------

    names = [
        pretty_pathway(
            x,
            34
        )
        for x in
        top_pathways["pathway"]
    ]

    axes[1].barh(
        names,
        top_pathways[
            "mean_abs_shap"
        ],
        color=PURPLE,
        alpha=0.9
    )

    axes[1].set_xlabel(
        "Mean absolute SHAP value"
    )

    axes[1].set_title(
        "B  Pathway-level importance",
        loc="left",
        fontweight="bold"
    )

    axes[1].grid(
        axis="x",
        alpha=0.15
    )

    axes[1].spines[
        "top"
    ].set_visible(False)

    axes[1].spines[
        "right"
    ].set_visible(False)

    fig.suptitle(
        "GraphOmics-HCC biological interpretation",
        fontsize=15,
        fontweight="bold",
        y=1.01
    )

    fig.tight_layout()

    save_figure(
        fig,
        "Figure7_Explainability_Genes_Pathways"
    )

    genes.head(50).to_csv(
        TABLEDIR /
        "TableS1_Top50_Gene_Attributions.csv",
        index=False
    )

    pathways.head(50).to_csv(
        TABLEDIR /
        "TableS2_Top50_Pathway_SHAP.csv",
        index=False
    )


# ============================================================
# TABLE S3 — EXPLAINABILITY STABILITY
# ============================================================

stab_file = (
    RESULTS /
    "explanation_stability.json"
)

if stab_file.exists():

    with open(stab_file) as f:
        explain = json.load(f)

    stability_rows = []

    stability = explain.get(
        "stability",
        {}
    )

    for key, value in stability.items():

        if isinstance(
            value,
            dict
        ):
            row = {
                "Metric": key
            }

            row.update(value)

            stability_rows.append(
                row
            )

        else:
            stability_rows.append({
                "Metric": key,
                "Value": value
            })

    pd.DataFrame(
        stability_rows
    ).to_csv(
        TABLEDIR /
        "TableS3_Explanation_Stability.csv",
        index=False
    )

    sanity = explain.get(
        "sanity_checks",
        {}
    )

    pd.DataFrame(
        [
            {
                "Check": k,
                "Value": v
            }
            for k, v
            in sanity.items()
            if isinstance(
                v,
                (int, float)
            )
        ]
    ).to_csv(
        TABLEDIR /
        "TableS4_Explanation_Sanity_Checks.csv",
        index=False
    )


# ============================================================
# FIGURE 8 — KAPLAN–MEIER
# ============================================================

curve_file = (
    RESULTS /
    "survival_curves.csv"
)

if (
    curve_file.exists()
    and SURVIVAL
):

    curves = pd.read_csv(
        curve_file
    )

    tcga_surv = (
        SURVIVAL
        .get(
            "cohorts",
            {}
        )
        .get(
            "TCGA-LIHC",
            {}
        )
    )

    fig, ax = plt.subplots(
        figsize=(8.0, 6.3)
    )

    group_settings = {
        "low": (
            BLUE,
            "Low diagnostic score"
        ),
        "high": (
            RED,
            "High diagnostic score"
        )
    }

    for group in [
        "low",
        "high"
    ]:

        d = curves[
            curves["group"]
            == group
        ].sort_values(
            "time"
        )

        if len(d) == 0:
            continue

        color, label = (
            group_settings[group]
        )

        ax.step(
            d["time"],
            d["survival"],
            where="post",
            lw=2.5,
            color=color,
            label=label
        )

    ax.set_xlabel(
        "Overall survival (months)"
    )

    ax.set_ylabel(
        "Survival probability"
    )

    ax.set_ylim(
        0,
        1.02
    )

    ax.set_title(
        "Exploratory survival stratification in TCGA-LIHC",
        fontweight="bold",
        pad=12
    )

    txt = (
        f'n={tcga_surv.get("n", "NA")}, '
        f'events={tcga_surv.get("n_events", "NA")}\n'
        f'Log-rank p={tcga_surv.get("logrank_p", np.nan):.3g}\n'
        f'Median OS: '
        f'{tcga_surv.get("median_os_low", np.nan):.1f} vs '
        f'{tcga_surv.get("median_os_high", np.nan):.1f} months'
    )

    ax.text(
        0.97,
        0.96,
        txt,
        transform=ax.transAxes,
        ha="right",
        va="top",
        fontsize=9.5,
        bbox=dict(
            boxstyle="round,pad=0.5",
            facecolor="white",
            edgecolor="#CDD3D8",
            alpha=0.95
        )
    )

    ax.legend(
        frameon=False,
        loc="lower left"
    )

    ax.grid(
        alpha=0.15
    )

    clean_axes(ax)

    save_figure(
        fig,
        "Figure8_Kaplan_Meier_Survival"
    )


# ============================================================
# TABLE 6 — SURVIVAL
# ============================================================

survival_rows = []

for cohort, r in (
    SURVIVAL
    .get(
        "cohorts",
        {}
    )
    .items()
):

    if "skipped" in r:
        continue

    survival_rows.append({
        "Cohort": cohort,
        "n": r.get("n"),
        "Events": r.get(
            "n_events"
        ),
        "High_group_n": r.get(
            "n_high"
        ),
        "Low_group_n": r.get(
            "n_low"
        ),
        "Cutpoint": r.get(
            "cutpoint"
        ),
        "Logrank_p": r.get(
            "logrank_p"
        ),
        "Median_OS_high_months":
            r.get(
                "median_os_high"
            ),
        "Median_OS_low_months":
            r.get(
                "median_os_low"
            ),
        "HR_univariable":
            r.get(
                "hr_univariable"
            ),
        "HR_univariable_CI_low":
            (
                r.get(
                    "hr_univariable_ci",
                    [np.nan, np.nan]
                )[0]
            ),
        "HR_univariable_CI_high":
            (
                r.get(
                    "hr_univariable_ci",
                    [np.nan, np.nan]
                )[1]
            ),
        "HR_adjusted":
            r.get(
                "hr_adjusted"
            ),
        "HR_adjusted_CI_low":
            (
                r.get(
                    "hr_adjusted_ci",
                    [np.nan, np.nan]
                )[0]
            ),
        "HR_adjusted_CI_high":
            (
                r.get(
                    "hr_adjusted_ci",
                    [np.nan, np.nan]
                )[1]
            ),
        "Adjusted_p":
            r.get(
                "hr_adjusted_p"
            ),
        "C_index_score_only":
            r.get(
                "c_index"
            ),
        "C_index_clinical_only":
            r.get(
                "c_index_clinical_only"
            ),
        "C_index_adjusted":
            r.get(
                "c_index_adjusted"
            ),
        "Delta_C_index":
            r.get(
                "delta_c_index"
            ),
    })


survival_table = pd.DataFrame(
    survival_rows
)

survival_table.to_csv(
    TABLEDIR /
    "Table6_Exploratory_Survival.csv",
    index=False
)


# ============================================================
# EXCEL WORKBOOK
# ============================================================

excel_path = (
    OUT /
    "GraphOmics_HCC_Publication_Tables.xlsx"
)

tables = {
    "Table1_Cohorts":
        cohort_table,
    "Table2_Performance":
        performance_table,
    "Table3_Baselines":
        comparison,
    "Table4_Ablations":
        ablation_table,
    "Table5_Graph":
        graph_table,
    "Table6_Survival":
        survival_table,
}

if gene_file.exists():
    tables[
        "TableS1_Genes"
    ] = pd.read_csv(
        gene_file
    ).head(50)

if shap_file.exists():
    tables[
        "TableS2_Pathways"
    ] = pd.read_csv(
        shap_file
    ).head(50)


with pd.ExcelWriter(
    excel_path,
    engine="openpyxl"
) as writer:

    for sheet, df in tables.items():

        df.to_excel(
            writer,
            sheet_name=sheet[:31],
            index=False
        )


# ============================================================
# FORMAT EXCEL
# ============================================================

try:

    from openpyxl import load_workbook
    from openpyxl.styles import (
        PatternFill,
        Font,
        Alignment,
        Border,
        Side
    )

    wb = load_workbook(
        excel_path
    )

    header_fill = PatternFill(
        "solid",
        fgColor="2457A7"
    )

    header_font = Font(
        color="FFFFFF",
        bold=True
    )

    thin = Side(
        style="thin",
        color="D9DEE5"
    )

    border = Border(
        bottom=thin
    )

    for ws in wb.worksheets:

        ws.freeze_panes = "A2"
        ws.auto_filter.ref = (
            ws.dimensions
        )

        for cell in ws[1]:

            cell.fill = header_fill
            cell.font = header_font

            cell.alignment = Alignment(
                horizontal="center",
                vertical="center",
                wrap_text=True
            )

        for row in ws.iter_rows(
            min_row=2
        ):

            for cell in row:

                cell.border = border

                if isinstance(
                    cell.value,
                    float
                ):

                    cell.number_format = (
                        "0.0000"
                    )

        for column_cells in ws.columns:

            letter = (
                column_cells[0]
                .column_letter
            )

            width = 0

            for cell in column_cells:

                if cell.value is not None:

                    width = max(
                        width,
                        len(
                            str(
                                cell.value
                            )
                        )
                    )

            ws.column_dimensions[
                letter
            ].width = min(
                width + 2,
                38
            )

    wb.save(
        excel_path
    )

except Exception as exc:

    print(
        "Excel formatting warning:",
        exc
    )


# ============================================================
# SUMMARY
# ============================================================

print("\n" + "=" * 80)
print("PUBLICATION OUTPUTS COMPLETE")
print("=" * 80)

print("\nFigures:")
for f in sorted(
    FIGDIR.glob("*")
):
    print(" ", f)

print("\nTables:")
for f in sorted(
    TABLEDIR.glob("*")
):
    print(" ", f)

print("\nExcel workbook:")
print(" ", excel_path)
# Out:
# Overwriting src/07_make_publication_figures.py

# %%
# %cd /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code

# !python src/07_make_publication_figures.py
# Out:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE/code
# ✅ results/publication_outputs/figures/Figure1_GraphOmics_HCC_Workflow.png
# ✅ results/publication_outputs/figures/Figure1_GraphOmics_HCC_Workflow.pdf
# ✅ results/publication_outputs/figures/Figure2_Cohort_Composition.png
# ✅ results/publication_outputs/figures/Figure2_Cohort_Composition.pdf
# ✅ results/publication_outputs/figures/Figure3_ROC_Curves.png
# ✅ results/publication_outputs/figures/Figure3_ROC_Curves.pdf
# ✅ results/publication_outputs/figures/FigureS1_Precision_Recall_Curves.png
# ✅ results/publication_outputs/figures/FigureS1_Precision_Recall_Curves.pdf
# ✅ results/publication_outputs/figures/Figure4_External_AUROC_Forest.png
# ✅ results/publication_outputs/figures/Figure4_External_AUROC_Forest.pdf
# ✅ results/publication_outputs/figures/Figure5_Model_Comparison_Heatmap.png
# ✅ results/publication_outputs/figures/Figure5_Model_Comparison_Heatmap.pdf
# ...

# %%
from pathlib import Path
from IPython.display import display, Image, Markdown

figdir = Path("results/publication_outputs/figures")

for f in sorted(figdir.glob("*.png")):
    display(Markdown(f"### {f.stem}"))
    display(Image(filename=str(f), width=950))
# Out:
# ### Figure1_GraphOmics_HCC_Workflow
# ### Figure2_Cohort_Composition
# ### Figure3_ROC_Curves
# ### Figure4_External_AUROC_Forest
# ### Figure5_Model_Comparison_Heatmap
# ### Figure6_Ablation_Delta_AUROC
# ### Figure7_Explainability_Genes_Pathways
# ### Figure8_Kaplan_Meier_Survival
# ### FigureS1_Precision_Recall_Curves

# %%
import shutil

shutil.make_archive(
    "GraphOmics_HCC_Publication_Outputs",
    "zip",
    "results/publication_outputs"
)

print("✅ ZIP created")
# Out:
# ✅ ZIP created

# %%
# %cd /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE

# !zip -r /content/GraphOmics_HCC_FINAL_CODE.zip code \
    -x "code/data/raw/*" \
       "code/data/processed/*" \
       "code/results/*" \
       "*/__pycache__/*" \
       "*.pyc"

print("✅ Complete code ZIP created")
# Out:
# /content/GraphOmics_HCC/GraphOmics_HCC_COMPLETE_RUNNABLE
#   adding: code/ (stored 0%)
#   adding: code/requirements_cloud.txt (deflated 32%)
#   adding: code/run_smoke.sh (deflated 53%)
#   adding: code/tests/ (stored 0%)
#   adding: code/tests/test_pipeline.py (deflated 63%)
#   adding: code/tests/test_corrected_controls.py (deflated 60%)
#   adding: code/check_inputs.sh (deflated 51%)
#   adding: code/figures/ (stored 0%)
#   adding: code/03_RUN_COMPLETE_REAL_ANALYSIS.sh (deflated 44%)
#   adding: code/04_COLLECT_RESULTS.sh (deflated 38%)
#   adding: code/GraphOmics_HCC_Publication_Outputs.zip (stored 0%)
#   adding: code/figures_smoke/ (stored 0%)
#   adding: code/run_smoke_local.sh (deflated 53%)
#   adding: code/00_BOOTSTRAP_ENVIRONMENT.sh (deflated 42%)
#   adding: code/config/ (stored 0%)
#   adding: code/config/geo_label_maps.yaml (deflated 57%)
#   adding: code/config/config.yaml (deflated 53%)
#   adding: code/config/config_original.yaml (deflated 51%)
# ...
